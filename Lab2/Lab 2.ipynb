# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %%
class Graph():
    
    def __init__(self, vertices):
        self.V = vertices
        self.matrixgraph = np.random.randint(0,11, (vertices, vertices))
        for i in range(vertices):
            for j in range(vertices):
                if i == j:
                    self.matrixgraph[i][j] = 0
        
        self.listgraph = {}
        for i in range(vertices):
            self.listgraph[i] = []
            
        for i in range(vertices):
            for j in range(vertices):
                if self.matrixgraph[i][j] != 0:
                    temp = [j, self.matrixgraph[i][j]]
                    self.listgraph[i].append(temp)
                    
    def getMatrix(self):
        print("Adjacency Matrix for the graph,")
        print(g.matrixgraph)
    
    def getList(self):
        print("Adjacency List for the graph,")
        for nodes in self.listgraph:
            print(nodes, end = "")
            for edges in self.listgraph[nodes]:
                print(" -> ", edges[0], "Weight:", edges[1], end = "")
            print()
            
    def visualize(self):
        G = nx.from_numpy_matrix(np.matrix(g.matrixgraph), create_using=nx.DiGraph)
        layout = nx.spring_layout(G)
        nx.draw(G, layout, with_labels=True)
        labels = nx.get_edge_attributes(G, "weight")
        nx.draw_networkx_edge_labels(G, pos=layout, edge_labels=labels)
        plt.show()

# %%
g = Graph(5)
g.getMatrix()
print()
g.getList()
g.visualize()
# Out:
# Adjacency Matrix for the graph,
# [[ 0  6  7  4  5]
#  [ 5  0 10  9  9]
#  [ 8  5  0  5  7]
#  [ 6  7  9  0  3]
#  [ 1  1  7  8  0]]
#
# Adjacency List for the graph,
# 0 ->  1 Weight: 6 ->  2 Weight: 7 ->  3 Weight: 4 ->  4 Weight: 5
# 1 ->  0 Weight: 5 ->  2 Weight: 10 ->  3 Weight: 9 ->  4 Weight: 9
# 2 ->  0 Weight: 8 ->  1 Weight: 5 ->  3 Weight: 5 ->  4 Weight: 7
# 3 ->  0 Weight: 6 ->  1 Weight: 7 ->  2 Weight: 9 ->  4 Weight: 3
# 4 ->  0 Weight: 1 ->  1 Weight: 1 ->  2 Weight: 7 ->  3 Weight: 8
