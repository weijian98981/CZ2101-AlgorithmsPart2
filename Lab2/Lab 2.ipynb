# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import sys
import timeit
import heapq

# %%
resultA = []
resultB = []

# %%
class Graph():
    
    def __init__(self, vertices):
        self.V = vertices
        self.matrixgraph = []
        self.listgraph = {}
    
    def generateNew(self):
        self.matrixgraph = np.random.randint(0,10, (self.V, self.V)) #Generate random adj matrix + set limit of weights
        
        for i in range(self.V):                                     #Set diagonal of adj matrix to 0, this is to eliminate loops
            for j in range(self.V):
                if i == j:
                    self.matrixgraph[i][j] = 0
                    
        for i in range(2, self.V):               # Assumes that node 0 is our source node, eliminates all other edges except
            self.matrixgraph[0][i] = 0           # the edge from node 0 -> node 1.
        for i in range(1, self.V):
            self.matrixgraph[i][0] = 0
        
        if self.matrixgraph[0][1] == 0:          # Incase of bad RNG, form connection from source to node 1
            self.matrixgraph[0][1] = 1
            
        self.convertToAdj()                                         #Convert from Adj matrix to Adj list
                    
    def getMatrix(self):                                            #Prints the adj matrix
        print("Adjacency Matrix for the graph,")
        print(g.matrixgraph)
    
    def getList(self):                                              #Prints the adj list
        print("Adjacency List for the graph,")
        for nodes in self.listgraph:
            print(nodes, end = "")
            for edges in self.listgraph[nodes]:
                print(" -> ", edges[0], "Weight:", edges[1], end = "")
            print()
            
    def visualize(self):                                            #Visualize the graph
        G = nx.from_numpy_matrix(np.matrix(g.matrixgraph), create_using=nx.DiGraph)
        layout = nx.spring_layout(G)
        nx.draw(G, layout, with_labels=True)
        labels = nx.get_edge_attributes(G, "weight")
        nx.draw_networkx_edge_labels(G, pos=layout, edge_labels=labels)
        plt.show()
        
    def convertToAdj(self):
        for i in range(self.V):                                     #Creation of adj list using adj matrix
            self.listgraph[i] = []
        for i in range(self.V):
            for j in range(self.V):
                if self.matrixgraph[i][j] != 0:
                    temp = [j, self.matrixgraph[i][j]]
                    self.listgraph[i].append(temp)

# %%
g = Graph(1000)
g.generateNew()
g.getMatrix()
print()
# g.getList()
# print()
# g.visualize()
# Out:
# Adjacency Matrix for the graph,
# [[0 8 0 ... 0 0 0]
#  [0 0 7 ... 5 0 1]
#  [0 8 0 ... 1 7 0]
#  ...
#  [0 1 6 ... 0 0 5]
#  [0 9 3 ... 2 0 3]
#  [0 1 8 ... 6 2 0]]

# %% [markdown]
# Part (a) - Implementation of Dijkstra's algorithm using adjacency matrix + array for priority queue

# %%
class Node():
    
    def __init__(self, vertex, weight):
        self.vertex = vertex
        self.weight = weight

# %%
class PriorityQueue:

    def __init__(self):
        self.q = []

    def insert(self, node):
        if len(self.q) == 0:
            self.q.append(node)
        else:
            for i in range(len(self.q)):
                if node.weight < self.q[i].weight:
                    self.q.insert(i, node)
                    break
                elif node.weight == self.q[i].weight:
                    pass

                if i == len(self.q) - 1:
                    self.q.insert(i + 1, node)

    def getMinNode(self):
        return self.q[0].vertex

    def getMinWeight(self):
        return self.q[0].weight

    def pop(self):
        self.q.pop(0)

    def show(self):
        print("Current priority queue,")
        for i in range(len(self.q)):
            print(self.q[i].vertex, "- Weight", self.q[i].weight)

    def isEmpty(self):
        return len(self.q) == 0

    def removeNode(self, index):
        for i in range(len(self.q)):
            if self.q[i].vertex == index:
                self.q.pop(i)
                break

# %%
def DijkstraA(G, source):
    time_start = timeit.default_timer()
    
    distance = [sys.maxsize] * G.V  # Original distance for all vertices are set to infinity
    path = [[] for i in range(G.V)]  # Initialize N number of sub-lists to store the path to each node
    S = [False] * G.V  # Initialize False to all the nodes since shortest path not yet discovered

    distance[source] = 0  # Set distance of source node to be zero
    pQueue = PriorityQueue()

    for i in range(G.V):  # Insert all the vertices into priority queue
        tempNode = Node(i, distance[i])
        pQueue.insert(tempNode)

    while (not pQueue.isEmpty()):
        u = pQueue.getMinNode()
        pQueue.pop()
        S[u] = True

        for i in range(G.V):
            if G.matrixgraph[u][i] != 0:
                if S[i] != True and distance[i] > distance[u] + G.matrixgraph[u][i]:
                    pQueue.removeNode(i)
                    distance[i] = distance[u] + G.matrixgraph[u][i]                   
                    if source not in path[i]:
                        for elements in path[u]:
                            path[i].append(elements)
                    path[i].append(u)
                    pQueue.insert(Node(i, distance[i]))
    
    time_stop = timeit.default_timer()
    #END OF DIJKSTRA ALGORITHM
    
    #Print results
    print("Time elapsed for program: ", (time_stop - time_start)*1000, "milliseconds")  # Time in milliseconds
    print("Distance from source node,")
    for i in range(0, G.V):
        if distance[i] == sys.maxsize:
            print("Source to node", i, ": No such path exist")
        else:
            print("Source to node", i, ":", distance[i])
        resultA.append(distance[i])
    
    print()
    print("Path to get to each node,")
    
    for i in range(0, G.V):
        print("Path from source to node", i)
        print(path[i])
        print()

# %%
DijkstraA(g, 0)
# Out:
# Time elapsed for program:  1999.20419999998 milliseconds
# Distance from source node,
# Source to node 0 : 0
# Source to node 1 : 8
# Source to node 2 : 10
# Source to node 3 : 10
# Source to node 4 : 10
# Source to node 5 : 10
# Source to node 6 : 10
# Source to node 7 : 10
# Source to node 8 : 10
# Source to node 9 : 10
# Source to node 10 : 10
# Source to node 11 : 9
# Source to node 12 : 10
# Source to node 13 : 10
# Source to node 14 : 10
# Source to node 15 : 10
# Source to node 16 : 10
# Source to node 17 : 10
# Source to node 18 : 10
# Source to node 19 : 10
# Source to node 20 : 10
# Source to node 21 : 10
# Source to node 22 : 10
# Source to node 23 : 10
# Source to node 24 : 10
# Source to node 25 : 10
# Source to node 26 : 10
# Source to node 27 : 10
# Source to node 28 : 10
# Source to node 29 : 10
# Source to node 30 : 9
# Source to node 31 : 10
# Source to node 32 : 10
# Source to node 33 : 10
# Source to node 34 : 10
# Source to node 35 : 10
# Source to node 36 : 10
# Source to node 37 : 10
# Source to node 38 : 10
# Source to node 39 : 10
# Source to node 40 : 10
# Source to node 41 : 10
# Source to node 42 : 10
# Source to node 43 : 10
# Source to node 44 : 9
# Source to node 45 : 10
# Source to node 46 : 10
# Source to node 47 : 9
# Source to node 48 : 9
# Source to node 49 : 10
# Source to node 50 : 10
# Source to node 51 : 10
# Source to node 52 : 10
# Source to node 53 : 10
# Source to node 54 : 10
# Source to node 55 : 10
# Source to node 56 : 10
# Source to node 57 : 10
# Source to node 58 : 10
# Source to node 59 : 10
# Source to node 60 : 10
# Source to node 61 : 10
# Source to node 62 : 10
# Source to node 63 : 9
# Source to node 64 : 10
# Source to node 65 : 10
# Source to node 66 : 10
# Source to node 67 : 10
# Source to node 68 : 9
# Source to node 69 : 10
# Source to node 70 : 9
# Source to node 71 : 10
# Source to node 72 : 9
# Source to node 73 : 10
# Source to node 74 : 10
# Source to node 75 : 10
# Source to node 76 : 10
# Source to node 77 : 10
# Source to node 78 : 10
# Source to node 79 : 10
# Source to node 80 : 10
# Source to node 81 : 10
# Source to node 82 : 10
# Source to node 83 : 10
# Source to node 84 : 10
# Source to node 85 : 9
# Source to node 86 : 10
# Source to node 87 : 9
# Source to node 88 : 10
# Source to node 89 : 9
# Source to node 90 : 9
# Source to node 91 : 10
# Source to node 92 : 10
# Source to node 93 : 10
# Source to node 94 : 10
# Source to node 95 : 10
# Source to node 96 : 10
# Source to node 97 : 10
# Source to node 98 : 10
# Source to node 99 : 10
# Source to node 100 : 10
# Source to node 101 : 9
# Source to node 102 : 10
# Source to node 103 : 9
# Source to node 104 : 10
# Source to node 105 : 10
# Source to node 106 : 10
# Source to node 107 : 10
# Source to node 108 : 10
# Source to node 109 : 10
# Source to node 110 : 10
# Source to node 111 : 10
# Source to node 112 : 9
# Source to node 113 : 10
# Source to node 114 : 10
# Source to node 115 : 10
# Source to node 116 : 10
# Source to node 117 : 9
# Source to node 118 : 10
# Source to node 119 : 10
# Source to node 120 : 10
# Source to node 121 : 9
# Source to node 122 : 9
# Source to node 123 : 10
# Source to node 124 : 10
# Source to node 125 : 9
# Source to node 126 : 10
# Source to node 127 : 10
# Source to node 128 : 10
# Source to node 129 : 10
# Source to node 130 : 9
# Source to node 131 : 10
# Source to node 132 : 10
# Source to node 133 : 10
# Source to node 134 : 9
# Source to node 135 : 10
# Source to node 136 : 9
# Source to node 137 : 10
# Source to node 138 : 10
# Source to node 139 : 10
# Source to node 140 : 10
# Source to node 141 : 10
# Source to node 142 : 10
# Source to node 143 : 10
# Source to node 144 : 10
# Source to node 145 : 10
# Source to node 146 : 10
# Source to node 147 : 9
# Source to node 148 : 10
# Source to node 149 : 10
# Source to node 150 : 10
# Source to node 151 : 10
# Source to node 152 : 10
# Source to node 153 : 10
# Source to node 154 : 10
# Source to node 155 : 10
# Source to node 156 : 10
# Source to node 157 : 10
# Source to node 158 : 9
# Source to node 159 : 10
# Source to node 160 : 10
# Source to node 161 : 10
# Source to node 162 : 10
# Source to node 163 : 9
# Source to node 164 : 10
# Source to node 165 : 10
# Source to node 166 : 10
# Source to node 167 : 10
# Source to node 168 : 10
# Source to node 169 : 10
# Source to node 170 : 9
# Source to node 171 : 10
# Source to node 172 : 10
# Source to node 173 : 10
# Source to node 174 : 10
# Source to node 175 : 10
# Source to node 176 : 10
# Source to node 177 : 10
# Source to node 178 : 10
# Source to node 179 : 10
# Source to node 180 : 10
# Source to node 181 : 10
# Source to node 182 : 10
# Source to node 183 : 10
# Source to node 184 : 10
# Source to node 185 : 10
# Source to node 186 : 10
# Source to node 187 : 10
# Source to node 188 : 10
# Source to node 189 : 10
# Source to node 190 : 10
# Source to node 191 : 10
# Source to node 192 : 9
# Source to node 193 : 10
# Source to node 194 : 9
# Source to node 195 : 10
# Source to node 196 : 10
# Source to node 197 : 10
# Source to node 198 : 10
# Source to node 199 : 10
# Source to node 200 : 10
# Source to node 201 : 10
# Source to node 202 : 10
# Source to node 203 : 10
# Source to node 204 : 10
# Source to node 205 : 10
# Source to node 206 : 10
# Source to node 207 : 10
# Source to node 208 : 10
# Source to node 209 : 10
# Source to node 210 : 10
# Source to node 211 : 9
# Source to node 212 : 10
# Source to node 213 : 10
# Source to node 214 : 10
# Source to node 215 : 10
# Source to node 216 : 10
# Source to node 217 : 10
# Source to node 218 : 10
# Source to node 219 : 10
# Source to node 220 : 10
# Source to node 221 : 10
# Source to node 222 : 10
# Source to node 223 : 10
# Source to node 224 : 10
# Source to node 225 : 10
# Source to node 226 : 10
# Source to node 227 : 10
# Source to node 228 : 10
# Source to node 229 : 10
# Source to node 230 : 9
# Source to node 231 : 10
# Source to node 232 : 10
# Source to node 233 : 10
# Source to node 234 : 10
# Source to node 235 : 10
# Source to node 236 : 10
# Source to node 237 : 10
# Source to node 238 : 10
# Source to node 239 : 9
# Source to node 240 : 10
# Source to node 241 : 10
# Source to node 242 : 10
# Source to node 243 : 10
# Source to node 244 : 10
# Source to node 245 : 10
# Source to node 246 : 10
# Source to node 247 : 10
# Source to node 248 : 10
# Source to node 249 : 10
# Source to node 250 : 9
# Source to node 251 : 10
# Source to node 252 : 10
# Source to node 253 : 10
# Source to node 254 : 10
# Source to node 255 : 10
# Source to node 256 : 10
# Source to node 257 : 10
# Source to node 258 : 10
# Source to node 259 : 10
# Source to node 260 : 10
# Source to node 261 : 10
# Source to node 262 : 10
# Source to node 263 : 10
# Source to node 264 : 10
# Source to node 265 : 10
# Source to node 266 : 10
# Source to node 267 : 10
# Source to node 268 : 10
# Source to node 269 : 10
# Source to node 270 : 10
# Source to node 271 : 10
# Source to node 272 : 10
# Source to node 273 : 10
# Source to node 274 : 10
# Source to node 275 : 10
# Source to node 276 : 10
# Source to node 277 : 10
# Source to node 278 : 10
# Source to node 279 : 10
# Source to node 280 : 10
# Source to node 281 : 10
# Source to node 282 : 10
# Source to node 283 : 10
# Source to node 284 : 10
# Source to node 285 : 10
# Source to node 286 : 10
# Source to node 287 : 10
# Source to node 288 : 10
# Source to node 289 : 10
# Source to node 290 : 10
# Source to node 291 : 9
# Source to node 292 : 9
# Source to node 293 : 10
# Source to node 294 : 10
# Source to node 295 : 10
# Source to node 296 : 10
# Source to node 297 : 10
# Source to node 298 : 10
# Source to node 299 : 10
# Source to node 300 : 10
# Source to node 301 : 10
# Source to node 302 : 10
# Source to node 303 : 10
# Source to node 304 : 10
# Source to node 305 : 9
# Source to node 306 : 10
# Source to node 307 : 10
# Source to node 308 : 10
# Source to node 309 : 10
# Source to node 310 : 10
# Source to node 311 : 10
# Source to node 312 : 10
# Source to node 313 : 10
# Source to node 314 : 10
# Source to node 315 : 10
# Source to node 316 : 9
# Source to node 317 : 10
# Source to node 318 : 10
# Source to node 319 : 10
# Source to node 320 : 10
# Source to node 321 : 10
# Source to node 322 : 10
# Source to node 323 : 10
# Source to node 324 : 10
# Source to node 325 : 10
# Source to node 326 : 10
# Source to node 327 : 10
# Source to node 328 : 9
# Source to node 329 : 10
# Source to node 330 : 10
# Source to node 331 : 10
# Source to node 332 : 9
# Source to node 333 : 10
# Source to node 334 : 10
# Source to node 335 : 10
# Source to node 336 : 9
# Source to node 337 : 10
# Source to node 338 : 10
# Source to node 339 : 10
# Source to node 340 : 10
# Source to node 341 : 9
# Source to node 342 : 10
# Source to node 343 : 10
# Source to node 344 : 10
# Source to node 345 : 10
# Source to node 346 : 9
# Source to node 347 : 9
# Source to node 348 : 10
# Source to node 349 : 10
# Source to node 350 : 10
# Source to node 351 : 10
# Source to node 352 : 10
# Source to node 353 : 10
# Source to node 354 : 10
# Source to node 355 : 10
# Source to node 356 : 10
# Source to node 357 : 10
# Source to node 358 : 10
# Source to node 359 : 10
# Source to node 360 : 10
# Source to node 361 : 10
# Source to node 362 : 10
# Source to node 363 : 10
# Source to node 364 : 10
# Source to node 365 : 10
# Source to node 366 : 10
# Source to node 367 : 10
# Source to node 368 : 10
# Source to node 369 : 10
# Source to node 370 : 10
# Source to node 371 : 10
# Source to node 372 : 10
# Source to node 373 : 10
# Source to node 374 : 10
# Source to node 375 : 10
# Source to node 376 : 10
# Source to node 377 : 10
# Source to node 378 : 10
# Source to node 379 : 10
# Source to node 380 : 10
# Source to node 381 : 10
# Source to node 382 : 10
# Source to node 383 : 10
# Source to node 384 : 10
# Source to node 385 : 10
# Source to node 386 : 10
# Source to node 387 : 10
# Source to node 388 : 10
# Source to node 389 : 10
# Source to node 390 : 10
# Source to node 391 : 10
# Source to node 392 : 10
# Source to node 393 : 10
# Source to node 394 : 10
# Source to node 395 : 10
# Source to node 396 : 10
# Source to node 397 : 9
# Source to node 398 : 10
# Source to node 399 : 10
# Source to node 400 : 10
# Source to node 401 : 10
# Source to node 402 : 10
# Source to node 403 : 10
# Source to node 404 : 10
# Source to node 405 : 10
# Source to node 406 : 10
# Source to node 407 : 10
# Source to node 408 : 10
# Source to node 409 : 10
# Source to node 410 : 9
# Source to node 411 : 10
# Source to node 412 : 9
# Source to node 413 : 10
# Source to node 414 : 10
# Source to node 415 : 10
# Source to node 416 : 10
# Source to node 417 : 10
# Source to node 418 : 10
# Source to node 419 : 10
# Source to node 420 : 9
# Source to node 421 : 10
# Source to node 422 : 10
# Source to node 423 : 10
# Source to node 424 : 10
# Source to node 425 : 9
# Source to node 426 : 10
# Source to node 427 : 10
# Source to node 428 : 10
# Source to node 429 : 9
# Source to node 430 : 10
# Source to node 431 : 10
# Source to node 432 : 10
# Source to node 433 : 10
# Source to node 434 : 10
# Source to node 435 : 10
# Source to node 436 : 10
# Source to node 437 : 10
# Source to node 438 : 10
# Source to node 439 : 10
# Source to node 440 : 10
# Source to node 441 : 10
# Source to node 442 : 10
# Source to node 443 : 10
# Source to node 444 : 10
# Source to node 445 : 10
# Source to node 446 : 10
# Source to node 447 : 10
# Source to node 448 : 10
# Source to node 449 : 10
# Source to node 450 : 10
# Source to node 451 : 10
# Source to node 452 : 10
# Source to node 453 : 10
# Source to node 454 : 10
# Source to node 455 : 10
# Source to node 456 : 10
# Source to node 457 : 10
# Source to node 458 : 10
# Source to node 459 : 10
# Source to node 460 : 10
# Source to node 461 : 10
# Source to node 462 : 10
# Source to node 463 : 10
# Source to node 464 : 10
# Source to node 465 : 10
# Source to node 466 : 9
# Source to node 467 : 10
# Source to node 468 : 10
# Source to node 469 : 10
# Source to node 470 : 10
# Source to node 471 : 10
# Source to node 472 : 10
# Source to node 473 : 10
# Source to node 474 : 10
# Source to node 475 : 10
# Source to node 476 : 10
# Source to node 477 : 10
# Source to node 478 : 10
# Source to node 479 : 9
# Source to node 480 : 10
# Source to node 481 : 10
# Source to node 482 : 10
# Source to node 483 : 10
# Source to node 484 : 10
# Source to node 485 : 10
# Source to node 486 : 10
# Source to node 487 : 10
# Source to node 488 : 10
# Source to node 489 : 10
# Source to node 490 : 9
# Source to node 491 : 10
# Source to node 492 : 10
# Source to node 493 : 10
# Source to node 494 : 10
# Source to node 495 : 10
# Source to node 496 : 10
# Source to node 497 : 10
# Source to node 498 : 10
# Source to node 499 : 10
# Source to node 500 : 9
# Source to node 501 : 9
# Source to node 502 : 9
# Source to node 503 : 10
# Source to node 504 : 10
# Source to node 505 : 9
# Source to node 506 : 10
# Source to node 507 : 10
# Source to node 508 : 10
# Source to node 509 : 10
# Source to node 510 : 9
# Source to node 511 : 10
# Source to node 512 : 10
# Source to node 513 : 9
# Source to node 514 : 10
# Source to node 515 : 10
# Source to node 516 : 10
# Source to node 517 : 10
# Source to node 518 : 10
# Source to node 519 : 10
# Source to node 520 : 10
# Source to node 521 : 10
# Source to node 522 : 10
# Source to node 523 : 10
# Source to node 524 : 10
# Source to node 525 : 10
# Source to node 526 : 10
# Source to node 527 : 10
# Source to node 528 : 9
# Source to node 529 : 10
# Source to node 530 : 10
# Source to node 531 : 9
# Source to node 532 : 10
# Source to node 533 : 10
# Source to node 534 : 10
# Source to node 535 : 10
# Source to node 536 : 10
# Source to node 537 : 10
# Source to node 538 : 10
# Source to node 539 : 10
# Source to node 540 : 10
# Source to node 541 : 10
# Source to node 542 : 9
# Source to node 543 : 10
# Source to node 544 : 10
# Source to node 545 : 10
# Source to node 546 : 10
# Source to node 547 : 10
# Source to node 548 : 10
# Source to node 549 : 10
# Source to node 550 : 10
# Source to node 551 : 10
# Source to node 552 : 10
# Source to node 553 : 10
# Source to node 554 : 10
# Source to node 555 : 10
# Source to node 556 : 10
# Source to node 557 : 10
# Source to node 558 : 10
# Source to node 559 : 10
# Source to node 560 : 10
# Source to node 561 : 10
# Source to node 562 : 10
# Source to node 563 : 10
# Source to node 564 : 10
# Source to node 565 : 10
# Source to node 566 : 10
# Source to node 567 : 10
# Source to node 568 : 10
# Source to node 569 : 9
# Source to node 570 : 10
# Source to node 571 : 10
# Source to node 572 : 10
# Source to node 573 : 10
# Source to node 574 : 10
# Source to node 575 : 10
# Source to node 576 : 10
# Source to node 577 : 10
# Source to node 578 : 10
# Source to node 579 : 10
# Source to node 580 : 10
# Source to node 581 : 10
# Source to node 582 : 10
# Source to node 583 : 9
# Source to node 584 : 10
# Source to node 585 : 10
# Source to node 586 : 10
# Source to node 587 : 10
# Source to node 588 : 10
# Source to node 589 : 10
# Source to node 590 : 10
# Source to node 591 : 10
# Source to node 592 : 10
# Source to node 593 : 9
# Source to node 594 : 10
# Source to node 595 : 10
# Source to node 596 : 10
# Source to node 597 : 10
# Source to node 598 : 10
# Source to node 599 : 10
# Source to node 600 : 10
# Source to node 601 : 10
# Source to node 602 : 10
# Source to node 603 : 10
# Source to node 604 : 10
# Source to node 605 : 10
# Source to node 606 : 10
# Source to node 607 : 10
# Source to node 608 : 10
# Source to node 609 : 10
# Source to node 610 : 10
# Source to node 611 : 10
# Source to node 612 : 10
# Source to node 613 : 10
# Source to node 614 : 10
# Source to node 615 : 10
# Source to node 616 : 10
# Source to node 617 : 10
# Source to node 618 : 10
# Source to node 619 : 10
# Source to node 620 : 10
# Source to node 621 : 10
# Source to node 622 : 10
# Source to node 623 : 10
# Source to node 624 : 10
# Source to node 625 : 10
# Source to node 626 : 10
# Source to node 627 : 10
# Source to node 628 : 10
# Source to node 629 : 10
# Source to node 630 : 10
# Source to node 631 : 10
# Source to node 632 : 10
# Source to node 633 : 9
# Source to node 634 : 10
# Source to node 635 : 10
# Source to node 636 : 10
# Source to node 637 : 10
# Source to node 638 : 10
# Source to node 639 : 10
# Source to node 640 : 10
# Source to node 641 : 10
# Source to node 642 : 10
# Source to node 643 : 10
# Source to node 644 : 10
# Source to node 645 : 10
# Source to node 646 : 10
# Source to node 647 : 10
# Source to node 648 : 10
# Source to node 649 : 10
# Source to node 650 : 10
# Source to node 651 : 10
# Source to node 652 : 10
# Source to node 653 : 10
# Source to node 654 : 10
# Source to node 655 : 10
# Source to node 656 : 10
# Source to node 657 : 10
# Source to node 658 : 10
# Source to node 659 : 10
# Source to node 660 : 9
# Source to node 661 : 10
# Source to node 662 : 10
# Source to node 663 : 10
# Source to node 664 : 10
# Source to node 665 : 10
# Source to node 666 : 10
# Source to node 667 : 9
# Source to node 668 : 10
# Source to node 669 : 10
# Source to node 670 : 10
# Source to node 671 : 10
# Source to node 672 : 9
# Source to node 673 : 10
# Source to node 674 : 10
# Source to node 675 : 10
# Source to node 676 : 10
# Source to node 677 : 10
# Source to node 678 : 10
# Source to node 679 : 10
# Source to node 680 : 10
# Source to node 681 : 10
# Source to node 682 : 10
# Source to node 683 : 10
# Source to node 684 : 10
# Source to node 685 : 10
# Source to node 686 : 10
# Source to node 687 : 10
# Source to node 688 : 10
# Source to node 689 : 10
# Source to node 690 : 10
# Source to node 691 : 9
# Source to node 692 : 10
# Source to node 693 : 10
# Source to node 694 : 10
# Source to node 695 : 10
# Source to node 696 : 10
# Source to node 697 : 10
# Source to node 698 : 10
# Source to node 699 : 10
# Source to node 700 : 10
# Source to node 701 : 10
# Source to node 702 : 10
# Source to node 703 : 10
# Source to node 704 : 10
# Source to node 705 : 10
# Source to node 706 : 9
# Source to node 707 : 9
# Source to node 708 : 10
# Source to node 709 : 10
# Source to node 710 : 9
# Source to node 711 : 10
# Source to node 712 : 10
# Source to node 713 : 10
# Source to node 714 : 10
# Source to node 715 : 10
# Source to node 716 : 9
# Source to node 717 : 10
# Source to node 718 : 10
# Source to node 719 : 10
# Source to node 720 : 10
# Source to node 721 : 10
# Source to node 722 : 9
# Source to node 723 : 10
# Source to node 724 : 10
# Source to node 725 : 10
# Source to node 726 : 10
# Source to node 727 : 9
# Source to node 728 : 10
# Source to node 729 : 10
# Source to node 730 : 10
# Source to node 731 : 10
# Source to node 732 : 10
# Source to node 733 : 10
# Source to node 734 : 9
# Source to node 735 : 10
# Source to node 736 : 9
# Source to node 737 : 10
# Source to node 738 : 9
# Source to node 739 : 9
# Source to node 740 : 9
# Source to node 741 : 9
# Source to node 742 : 10
# Source to node 743 : 10
# Source to node 744 : 10
# Source to node 745 : 10
# Source to node 746 : 10
# Source to node 747 : 9
# Source to node 748 : 10
# Source to node 749 : 10
# Source to node 750 : 10
# Source to node 751 : 10
# Source to node 752 : 10
# Source to node 753 : 10
# Source to node 754 : 10
# Source to node 755 : 10
# Source to node 756 : 9
# Source to node 757 : 10
# Source to node 758 : 10
# Source to node 759 : 10
# Source to node 760 : 10
# Source to node 761 : 10
# Source to node 762 : 10
# Source to node 763 : 10
# Source to node 764 : 10
# Source to node 765 : 10
# Source to node 766 : 10
# Source to node 767 : 10
# Source to node 768 : 10
# Source to node 769 : 10
# Source to node 770 : 10
# Source to node 771 : 10
# Source to node 772 : 10
# Source to node 773 : 10
# Source to node 774 : 10
# Source to node 775 : 9
# Source to node 776 : 10
# Source to node 777 : 10
# Source to node 778 : 10
# Source to node 779 : 10
# Source to node 780 : 10
# Source to node 781 : 10
# Source to node 782 : 9
# Source to node 783 : 10
# Source to node 784 : 10
# Source to node 785 : 9
# Source to node 786 : 10
# Source to node 787 : 10
# Source to node 788 : 10
# Source to node 789 : 9
# Source to node 790 : 10
# Source to node 791 : 10
# Source to node 792 : 10
# Source to node 793 : 10
# Source to node 794 : 10
# Source to node 795 : 10
# Source to node 796 : 9
# Source to node 797 : 10
# Source to node 798 : 9
# Source to node 799 : 10
# Source to node 800 : 10
# Source to node 801 : 9
# Source to node 802 : 10
# Source to node 803 : 10
# Source to node 804 : 10
# Source to node 805 : 10
# Source to node 806 : 10
# Source to node 807 : 10
# Source to node 808 : 10
# Source to node 809 : 10
# Source to node 810 : 10
# Source to node 811 : 10
# Source to node 812 : 10
# Source to node 813 : 10
# Source to node 814 : 10
# Source to node 815 : 10
# Source to node 816 : 10
# Source to node 817 : 10
# Source to node 818 : 10
# Source to node 819 : 10
# Source to node 820 : 10
# Source to node 821 : 10
# Source to node 822 : 10
# Source to node 823 : 10
# Source to node 824 : 10
# Source to node 825 : 10
# Source to node 826 : 9
# Source to node 827 : 10
# Source to node 828 : 10
# Source to node 829 : 10
# Source to node 830 : 9
# Source to node 831 : 10
# Source to node 832 : 10
# Source to node 833 : 10
# Source to node 834 : 10
# Source to node 835 : 9
# Source to node 836 : 10
# Source to node 837 : 10
# Source to node 838 : 10
# Source to node 839 : 10
# Source to node 840 : 10
# Source to node 841 : 10
# Source to node 842 : 9
# Source to node 843 : 10
# Source to node 844 : 9
# Source to node 845 : 10
# Source to node 846 : 10
# Source to node 847 : 10
# Source to node 848 : 10
# Source to node 849 : 10
# Source to node 850 : 10
# Source to node 851 : 10
# Source to node 852 : 10
# Source to node 853 : 10
# Source to node 854 : 10
# Source to node 855 : 10
# Source to node 856 : 10
# Source to node 857 : 10
# Source to node 858 : 10
# Source to node 859 : 10
# Source to node 860 : 10
# Source to node 861 : 10
# Source to node 862 : 10
# Source to node 863 : 10
# Source to node 864 : 10
# Source to node 865 : 10
# Source to node 866 : 10
# Source to node 867 : 10
# Source to node 868 : 10
# Source to node 869 : 10
# Source to node 870 : 10
# Source to node 871 : 10
# Source to node 872 : 10
# Source to node 873 : 10
# Source to node 874 : 10
# Source to node 875 : 9
# Source to node 876 : 10
# Source to node 877 : 10
# Source to node 878 : 10
# Source to node 879 : 10
# Source to node 880 : 10
# Source to node 881 : 10
# Source to node 882 : 10
# Source to node 883 : 10
# Source to node 884 : 10
# Source to node 885 : 10
# Source to node 886 : 10
# Source to node 887 : 10
# Source to node 888 : 10
# Source to node 889 : 10
# Source to node 890 : 10
# Source to node 891 : 10
# Source to node 892 : 10
# Source to node 893 : 10
# Source to node 894 : 10
# Source to node 895 : 10
# Source to node 896 : 10
# Source to node 897 : 10
# Source to node 898 : 10
# Source to node 899 : 10
# Source to node 900 : 10
# Source to node 901 : 10
# Source to node 902 : 10
# Source to node 903 : 10
# Source to node 904 : 10
# Source to node 905 : 10
# Source to node 906 : 10
# Source to node 907 : 10
# Source to node 908 : 10
# Source to node 909 : 10
# Source to node 910 : 10
# Source to node 911 : 9
# Source to node 912 : 10
# Source to node 913 : 10
# Source to node 914 : 9
# Source to node 915 : 10
# Source to node 916 : 10
# Source to node 917 : 10
# Source to node 918 : 10
# Source to node 919 : 10
# Source to node 920 : 10
# Source to node 921 : 10
# Source to node 922 : 10
# Source to node 923 : 10
# Source to node 924 : 10
# Source to node 925 : 10
# Source to node 926 : 9
# Source to node 927 : 10
# Source to node 928 : 10
# Source to node 929 : 10
# Source to node 930 : 10
# Source to node 931 : 10
# Source to node 932 : 10
# Source to node 933 : 10
# Source to node 934 : 10
# Source to node 935 : 10
# Source to node 936 : 9
# Source to node 937 : 10
# Source to node 938 : 10
# Source to node 939 : 10
# Source to node 940 : 10
# Source to node 941 : 10
# Source to node 942 : 10
# Source to node 943 : 10
# Source to node 944 : 10
# Source to node 945 : 10
# Source to node 946 : 10
# Source to node 947 : 10
# Source to node 948 : 10
# Source to node 949 : 10
# Source to node 950 : 10
# Source to node 951 : 10
# Source to node 952 : 10
# Source to node 953 : 10
# Source to node 954 : 10
# Source to node 955 : 10
# Source to node 956 : 10
# Source to node 957 : 10
# Source to node 958 : 10
# Source to node 959 : 10
# Source to node 960 : 9
# Source to node 961 : 10
# Source to node 962 : 10
# Source to node 963 : 9
# Source to node 964 : 10
# Source to node 965 : 10
# Source to node 966 : 10
# Source to node 967 : 10
# Source to node 968 : 10
# Source to node 969 : 10
# Source to node 970 : 10
# Source to node 971 : 10
# Source to node 972 : 10
# Source to node 973 : 10
# Source to node 974 : 9
# Source to node 975 : 10
# Source to node 976 : 10
# Source to node 977 : 10
# Source to node 978 : 10
# Source to node 979 : 10
# Source to node 980 : 10
# Source to node 981 : 10
# Source to node 982 : 10
# Source to node 983 : 10
# Source to node 984 : 10
# Source to node 985 : 10
# Source to node 986 : 9
# Source to node 987 : 10
# Source to node 988 : 10
# Source to node 989 : 10
# Source to node 990 : 10
# Source to node 991 : 10
# Source to node 992 : 10
# Source to node 993 : 10
# Source to node 994 : 10
# Source to node 995 : 10
# Source to node 996 : 10
# Source to node 997 : 10
# Source to node 998 : 10
# Source to node 999 : 9
#
# Path to get to each node,
# Path from source to node 0
# []
#
# Path from source to node 1
# [0]
#
# Path from source to node 2
# [0, 1, 11]
#
# Path from source to node 3
# [0, 1, 11, 85]
#
# Path from source to node 4
# [0, 1]
#
# Path from source to node 5
# [0, 1, 11, 63]
#
# Path from source to node 6
# [0, 1, 11, 347]
#
# Path from source to node 7
# [0, 1, 11]
#
# Path from source to node 8
# [0, 1, 11, 30, 47, 48, 87]
#
# Path from source to node 9
# [0, 1, 47, 87]
#
# Path from source to node 10
# [0, 1]
#
# Path from source to node 11
# [0, 1]
#
# Path from source to node 12
# [0, 1]
#
# Path from source to node 13
# [0, 1, 11, 44]
#
# Path from source to node 14
# [0, 1, 11, 44, 68]
#
# Path from source to node 15
# [0, 1, 30]
#
# Path from source to node 16
# [0, 1, 11, 30, 48, 68, 89]
#
# Path from source to node 17
# [0, 1, 30]
#
# Path from source to node 18
# [0, 1, 11, 158]
#
# Path from source to node 19
# [0, 1, 48]
#
# Path from source to node 20
# [0, 1, 11]
#
# Path from source to node 21
# [0, 1, 11, 63]
#
# Path from source to node 22
# [0, 1, 101, 122, 136]
#
# Path from source to node 23
# [0, 1, 11]
#
# Path from source to node 24
# [0, 1, 30, 68]
#
# Path from source to node 25
# [0, 1, 44]
#
# Path from source to node 26
# [0, 1, 30, 158]
#
# Path from source to node 27
# [0, 1, 11, 47]
#
# Path from source to node 28
# [0, 1, 30, 68, 89]
#
# Path from source to node 29
# [0, 1, 44]
#
# Path from source to node 30
# [0, 1]
#
# Path from source to node 31
# [0, 1, 11]
#
# Path from source to node 32
# [0, 1, 47]
#
# Path from source to node 33
# [0, 1]
#
# Path from source to node 34
# [0, 1]
#
# Path from source to node 35
# [0, 1, 47, 125]
#
# Path from source to node 36
# [0, 1, 63, 72]
#
# Path from source to node 37
# [0, 1]
#
# Path from source to node 38
# [0, 1, 11, 48]
#
# Path from source to node 39
# [0, 1, 122]
#
# Path from source to node 40
# [0, 1, 11, 68, 136]
#
# Path from source to node 41
# [0, 1, 11]
#
# Path from source to node 42
# [0, 1, 68]
#
# Path from source to node 43
# [0, 1, 11, 30]
#
# Path from source to node 44
# [0, 1]
#
# Path from source to node 45
# [0, 1, 11, 147]
#
# Path from source to node 46
# [0, 1, 11, 87]
#
# Path from source to node 47
# [0, 1]
#
# Path from source to node 48
# [0, 1]
#
# Path from source to node 49
# [0, 1, 11, 30, 47]
#
# Path from source to node 50
# [0, 1]
#
# Path from source to node 51
# [0, 1, 341]
#
# Path from source to node 52
# [0, 1, 11]
#
# Path from source to node 53
# [0, 1, 11, 30, 70]
#
# Path from source to node 54
# [0, 1, 30, 89, 90]
#
# Path from source to node 55
# [0, 1, 68]
#
# Path from source to node 56
# [0, 1, 11]
#
# Path from source to node 57
# [0, 1, 30, 134]
#
# Path from source to node 58
# [0, 1]
#
# Path from source to node 59
# [0, 1, 11, 30]
#
# Path from source to node 60
# [0, 1, 68]
#
# Path from source to node 61
# [0, 1, 11, 47, 63]
#
# Path from source to node 62
# [0, 1]
#
# Path from source to node 63
# [0, 1]
#
# Path from source to node 64
# [0, 1, 47, 70, 192]
#
# Path from source to node 65
# [0, 1, 163]
#
# Path from source to node 66
# [0, 1]
#
# Path from source to node 67
# [0, 1, 30, 44, 90]
#
# Path from source to node 68
# [0, 1]
#
# Path from source to node 69
# [0, 1, 11, 48, 158]
#
# Path from source to node 70
# [0, 1]
#
# Path from source to node 71
# [0, 1, 47]
#
# Path from source to node 72
# [0, 1]
#
# Path from source to node 73
# [0, 1, 48, 87]
#
# Path from source to node 74
# [0, 1, 44]
#
# Path from source to node 75
# [0, 1, 30, 44]
#
# Path from source to node 76
# [0, 1, 30]
#
# Path from source to node 77
# [0, 1, 11]
#
# Path from source to node 78
# [0, 1, 11]
#
# Path from source to node 79
# [0, 1, 89]
#
# Path from source to node 80
# [0, 1, 11]
#
# Path from source to node 81
# [0, 1, 11, 72]
#
# Path from source to node 82
# [0, 1, 112]
#
# Path from source to node 83
# [0, 1, 47, 48]
#
# Path from source to node 84
# [0, 1, 30, 44, 48, 122, 211]
#
# Path from source to node 85
# [0, 1]
#
# Path from source to node 86
# [0, 1, 30]
#
# Path from source to node 87
# [0, 1]
#
# Path from source to node 88
# [0, 1]
#
# Path from source to node 89
# [0, 1]
#
# Path from source to node 90
# [0, 1]
#
# Path from source to node 91
# [0, 1, 11, 30, 47]
#
# Path from source to node 92
# [0, 1, 30, 87, 136]
#
# Path from source to node 93
# [0, 1, 47, 68, 117]
#
# Path from source to node 94
# [0, 1, 11, 30, 48]
#
# Path from source to node 95
# [0, 1, 11, 30, 44, 90]
#
# Path from source to node 96
# [0, 1, 11]
#
# Path from source to node 97
# [0, 1, 11]
#
# Path from source to node 98
# [0, 1, 103]
#
# Path from source to node 99
# [0, 1, 30, 47]
#
# Path from source to node 100
# [0, 1, 68, 90]
#
# Path from source to node 101
# [0, 1]
#
# Path from source to node 102
# [0, 1, 87]
#
# Path from source to node 103
# [0, 1]
#
# Path from source to node 104
# [0, 1, 47, 48]
#
# Path from source to node 105
# [0, 1]
#
# Path from source to node 106
# [0, 1, 68, 72]
#
# Path from source to node 107
# [0, 1, 11, 30]
#
# Path from source to node 108
# [0, 1, 30, 47]
#
# Path from source to node 109
# [0, 1]
#
# Path from source to node 110
# [0, 1, 63]
#
# Path from source to node 111
# [0, 1, 30, 125]
#
# Path from source to node 112
# [0, 1]
#
# Path from source to node 113
# [0, 1, 30, 87]
#
# Path from source to node 114
# [0, 1, 11]
#
# Path from source to node 115
# [0, 1, 11, 89]
#
# Path from source to node 116
# [0, 1, 11, 48]
#
# Path from source to node 117
# [0, 1]
#
# Path from source to node 118
# [0, 1]
#
# Path from source to node 119
# [0, 1, 11, 90, 130]
#
# Path from source to node 120
# [0, 1, 44]
#
# Path from source to node 121
# [0, 1]
#
# Path from source to node 122
# [0, 1]
#
# Path from source to node 123
# [0, 1, 63, 68]
#
# Path from source to node 124
# [0, 1]
#
# Path from source to node 125
# [0, 1]
#
# Path from source to node 126
# [0, 1, 48]
#
# Path from source to node 127
# [0, 1, 63, 87]
#
# Path from source to node 128
# [0, 1, 11, 30, 48, 63]
#
# Path from source to node 129
# [0, 1]
#
# Path from source to node 130
# [0, 1]
#
# Path from source to node 131
# [0, 1, 11, 103]
#
# Path from source to node 132
# [0, 1]
#
# Path from source to node 133
# [0, 1, 47, 68, 85, 89]
#
# Path from source to node 134
# [0, 1]
#
# Path from source to node 135
# [0, 1, 30, 89, 158]
#
# Path from source to node 136
# [0, 1]
#
# Path from source to node 137
# [0, 1, 11, 30]
#
# Path from source to node 138
# [0, 1, 47]
#
# Path from source to node 139
# [0, 1, 11, 85]
#
# Path from source to node 140
# [0, 1, 11, 30, 47]
#
# Path from source to node 141
# [0, 1, 11, 44, 63, 103]
#
# Path from source to node 142
# [0, 1, 11]
#
# Path from source to node 143
# [0, 1, 11]
#
# Path from source to node 144
# [0, 1, 30, 47, 70]
#
# Path from source to node 145
# [0, 1]
#
# Path from source to node 146
# [0, 1, 11, 44, 87, 121]
#
# Path from source to node 147
# [0, 1]
#
# Path from source to node 148
# [0, 1, 87]
#
# Path from source to node 149
# [0, 1, 11]
#
# Path from source to node 150
# [0, 1, 30, 44, 63]
#
# Path from source to node 151
# [0, 1, 11]
#
# Path from source to node 152
# [0, 1, 11, 44, 68]
#
# Path from source to node 153
# [0, 1]
#
# Path from source to node 154
# [0, 1, 11, 68]
#
# Path from source to node 155
# [0, 1]
#
# Path from source to node 156
# [0, 1, 30, 44, 48, 70]
#
# Path from source to node 157
# [0, 1, 30, 44, 47, 425]
#
# Path from source to node 158
# [0, 1]
#
# Path from source to node 159
# [0, 1, 11, 30, 44]
#
# Path from source to node 160
# [0, 1, 30, 87]
#
# Path from source to node 161
# [0, 1, 11, 72]
#
# Path from source to node 162
# [0, 1, 11]
#
# Path from source to node 163
# [0, 1]
#
# Path from source to node 164
# [0, 1, 11, 30, 63, 68]
#
# Path from source to node 165
# [0, 1, 44, 63, 90]
#
# Path from source to node 166
# [0, 1, 30, 63]
#
# Path from source to node 167
# [0, 1, 11, 68]
#
# Path from source to node 168
# [0, 1, 11, 44]
#
# Path from source to node 169
# [0, 1, 11]
#
# Path from source to node 170
# [0, 1]
#
# Path from source to node 171
# [0, 1, 48, 101, 117]
#
# Path from source to node 172
# [0, 1, 48, 130]
#
# Path from source to node 173
# [0, 1, 11, 30, 89]
#
# Path from source to node 174
# [0, 1, 30, 44]
#
# Path from source to node 175
# [0, 1, 44]
#
# Path from source to node 176
# [0, 1, 11]
#
# Path from source to node 177
# [0, 1, 44, 85, 90]
#
# Path from source to node 178
# [0, 1, 11, 30, 48]
#
# Path from source to node 179
# [0, 1, 47]
#
# Path from source to node 180
# [0, 1, 11, 48, 72]
#
# Path from source to node 181
# [0, 1, 134]
#
# Path from source to node 182
# [0, 1, 11, 30]
#
# Path from source to node 183
# [0, 1, 11, 44, 101, 117, 239]
#
# Path from source to node 184
# [0, 1]
#
# Path from source to node 185
# [0, 1, 30, 44, 70]
#
# Path from source to node 186
# [0, 1]
#
# Path from source to node 187
# [0, 1, 47, 68, 122]
#
# Path from source to node 188
# [0, 1, 11, 70, 85]
#
# Path from source to node 189
# [0, 1]
#
# Path from source to node 190
# [0, 1, 11]
#
# Path from source to node 191
# [0, 1, 70]
#
# Path from source to node 192
# [0, 1]
#
# Path from source to node 193
# [0, 1, 117]
#
# Path from source to node 194
# [0, 1]
#
# Path from source to node 195
# [0, 1, 11, 47]
#
# Path from source to node 196
# [0, 1]
#
# Path from source to node 197
# [0, 1]
#
# Path from source to node 198
# [0, 1, 44, 89]
#
# Path from source to node 199
# [0, 1, 11, 30, 44, 47, 89]
#
# Path from source to node 200
# [0, 1, 11]
#
# Path from source to node 201
# [0, 1]
#
# Path from source to node 202
# [0, 1, 11]
#
# Path from source to node 203
# [0, 1, 47, 48]
#
# Path from source to node 204
# [0, 1, 11, 30, 44, 85]
#
# Path from source to node 205
# [0, 1]
#
# Path from source to node 206
# [0, 1, 11, 44, 89]
#
# Path from source to node 207
# [0, 1, 30, 47]
#
# Path from source to node 208
# [0, 1, 11, 70, 85, 101]
#
# Path from source to node 209
# [0, 1, 11]
#
# Path from source to node 210
# [0, 1, 30, 48]
#
# Path from source to node 211
# [0, 1]
#
# Path from source to node 212
# [0, 1, 44, 63]
#
# Path from source to node 213
# [0, 1, 11, 30]
#
# Path from source to node 214
# [0, 1, 44, 63, 101]
#
# Path from source to node 215
# [0, 1, 11, 68, 158]
#
# Path from source to node 216
# [0, 1, 11, 30]
#
# Path from source to node 217
# [0, 1, 11, 30, 63]
#
# Path from source to node 218
# [0, 1, 11, 85]
#
# Path from source to node 219
# [0, 1, 11, 136]
#
# Path from source to node 220
# [0, 1, 11, 103]
#
# Path from source to node 221
# [0, 1, 11, 87]
#
# Path from source to node 222
# [0, 1, 44, 136]
#
# Path from source to node 223
# [0, 1, 72]
#
# Path from source to node 224
# [0, 1, 134]
#
# Path from source to node 225
# [0, 1, 44, 68]
#
# Path from source to node 226
# [0, 1, 63]
#
# Path from source to node 227
# [0, 1, 11, 30, 47, 397]
#
# Path from source to node 228
# [0, 1, 44, 85, 87]
#
# Path from source to node 229
# [0, 1, 11, 30]
#
# Path from source to node 230
# [0, 1]
#
# Path from source to node 231
# [0, 1, 11, 30]
#
# Path from source to node 232
# [0, 1, 30, 117, 130]
#
# Path from source to node 233
# [0, 1, 30, 47]
#
# Path from source to node 234
# [0, 1, 11, 44]
#
# Path from source to node 235
# [0, 1, 44, 85]
#
# Path from source to node 236
# [0, 1, 30, 72, 479]
#
# Path from source to node 237
# [0, 1, 11, 44]
#
# Path from source to node 238
# [0, 1, 30, 68, 70]
#
# Path from source to node 239
# [0, 1]
#
# Path from source to node 240
# [0, 1, 11]
#
# Path from source to node 241
# [0, 1, 30, 47, 68]
#
# Path from source to node 242
# [0, 1, 30, 44]
#
# Path from source to node 243
# [0, 1, 11, 44, 47]
#
# Path from source to node 244
# [0, 1, 11, 47]
#
# Path from source to node 245
# [0, 1]
#
# Path from source to node 246
# [0, 1]
#
# Path from source to node 247
# [0, 1, 70, 103]
#
# Path from source to node 248
# [0, 1, 11]
#
# Path from source to node 249
# [0, 1, 44, 316]
#
# Path from source to node 250
# [0, 1]
#
# Path from source to node 251
# [0, 1]
#
# Path from source to node 252
# [0, 1, 11, 70]
#
# Path from source to node 253
# [0, 1, 11, 30]
#
# Path from source to node 254
# [0, 1, 30, 44]
#
# Path from source to node 255
# [0, 1, 11, 48, 63, 85]
#
# Path from source to node 256
# [0, 1, 70, 72]
#
# Path from source to node 257
# [0, 1, 44]
#
# Path from source to node 258
# [0, 1, 11, 30, 72]
#
# Path from source to node 259
# [0, 1, 48, 194]
#
# Path from source to node 260
# [0, 1, 44, 48]
#
# Path from source to node 261
# [0, 1, 11, 89, 125]
#
# Path from source to node 262
# [0, 1, 11, 44]
#
# Path from source to node 263
# [0, 1, 11, 30]
#
# Path from source to node 264
# [0, 1, 11, 89]
#
# Path from source to node 265
# [0, 1, 11, 70]
#
# Path from source to node 266
# [0, 1, 63]
#
# Path from source to node 267
# [0, 1, 11, 63]
#
# Path from source to node 268
# [0, 1, 11, 101, 136]
#
# Path from source to node 269
# [0, 1, 47]
#
# Path from source to node 270
# [0, 1]
#
# Path from source to node 271
# [0, 1, 11, 68]
#
# Path from source to node 272
# [0, 1]
#
# Path from source to node 273
# [0, 1, 11, 30, 63, 68, 72]
#
# Path from source to node 274
# [0, 1, 44]
#
# Path from source to node 275
# [0, 1, 44, 48]
#
# Path from source to node 276
# [0, 1]
#
# Path from source to node 277
# [0, 1, 47, 122]
#
# Path from source to node 278
# [0, 1, 11, 48, 72, 89]
#
# Path from source to node 279
# [0, 1, 89]
#
# Path from source to node 280
# [0, 1, 11, 44, 89]
#
# Path from source to node 281
# [0, 1, 11]
#
# Path from source to node 282
# [0, 1, 63, 134]
#
# Path from source to node 283
# [0, 1, 44, 48]
#
# Path from source to node 284
# [0, 1, 11]
#
# Path from source to node 285
# [0, 1, 11, 72]
#
# Path from source to node 286
# [0, 1, 72, 122]
#
# Path from source to node 287
# [0, 1, 44, 63, 68, 121]
#
# Path from source to node 288
# [0, 1, 11]
#
# Path from source to node 289
# [0, 1, 11]
#
# Path from source to node 290
# [0, 1, 11, 70]
#
# Path from source to node 291
# [0, 1]
#
# Path from source to node 292
# [0, 1]
#
# Path from source to node 293
# [0, 1, 11, 30, 44]
#
# Path from source to node 294
# [0, 1, 11, 122]
#
# Path from source to node 295
# [0, 1, 30, 48]
#
# Path from source to node 296
# [0, 1, 11, 85, 90]
#
# Path from source to node 297
# [0, 1, 11, 63, 101, 112]
#
# Path from source to node 298
# [0, 1, 30]
#
# Path from source to node 299
# [0, 1, 11]
#
# Path from source to node 300
# [0, 1, 63]
#
# Path from source to node 301
# [0, 1, 44]
#
# Path from source to node 302
# [0, 1]
#
# Path from source to node 303
# [0, 1, 11, 87]
#
# Path from source to node 304
# [0, 1, 30]
#
# Path from source to node 305
# [0, 1]
#
# Path from source to node 306
# [0, 1, 72]
#
# Path from source to node 307
# [0, 1]
#
# Path from source to node 308
# [0, 1, 63]
#
# Path from source to node 309
# [0, 1, 30, 48, 68]
#
# Path from source to node 310
# [0, 1, 30, 72, 121]
#
# Path from source to node 311
# [0, 1, 11, 30, 48]
#
# Path from source to node 312
# [0, 1, 44, 47, 48]
#
# Path from source to node 313
# [0, 1, 11]
#
# Path from source to node 314
# [0, 1, 63, 121]
#
# Path from source to node 315
# [0, 1]
#
# Path from source to node 316
# [0, 1]
#
# Path from source to node 317
# [0, 1, 70]
#
# Path from source to node 318
# [0, 1, 11, 63]
#
# Path from source to node 319
# [0, 1, 11, 68, 121, 130]
#
# Path from source to node 320
# [0, 1, 48]
#
# Path from source to node 321
# [0, 1, 47, 63]
#
# Path from source to node 322
# [0, 1]
#
# Path from source to node 323
# [0, 1, 11]
#
# Path from source to node 324
# [0, 1, 72]
#
# Path from source to node 325
# [0, 1, 11, 30, 89]
#
# Path from source to node 326
# [0, 1, 194]
#
# Path from source to node 327
# [0, 1, 502]
#
# Path from source to node 328
# [0, 1]
#
# Path from source to node 329
# [0, 1, 11]
#
# Path from source to node 330
# [0, 1, 44]
#
# Path from source to node 331
# [0, 1, 30]
#
# Path from source to node 332
# [0, 1]
#
# Path from source to node 333
# [0, 1, 30, 211]
#
# Path from source to node 334
# [0, 1, 30]
#
# Path from source to node 335
# [0, 1, 11, 63]
#
# Path from source to node 336
# [0, 1]
#
# Path from source to node 337
# [0, 1, 30, 72]
#
# Path from source to node 338
# [0, 1, 89]
#
# Path from source to node 339
# [0, 1, 11]
#
# Path from source to node 340
# [0, 1, 11, 63, 85]
#
# Path from source to node 341
# [0, 1]
#
# Path from source to node 342
# [0, 1, 11, 89]
#
# Path from source to node 343
# [0, 1, 30, 89, 134]
#
# Path from source to node 344
# [0, 1, 44, 47, 48]
#
# Path from source to node 345
# [0, 1]
#
# Path from source to node 346
# [0, 1]
#
# Path from source to node 347
# [0, 1]
#
# Path from source to node 348
# [0, 1, 11, 72]
#
# Path from source to node 349
# [0, 1, 11]
#
# Path from source to node 350
# [0, 1, 11]
#
# Path from source to node 351
# [0, 1, 194]
#
# Path from source to node 352
# [0, 1, 30, 48]
#
# Path from source to node 353
# [0, 1, 11]
#
# Path from source to node 354
# [0, 1, 30]
#
# Path from source to node 355
# [0, 1]
#
# Path from source to node 356
# [0, 1, 87, 117]
#
# Path from source to node 357
# [0, 1, 44, 305]
#
# Path from source to node 358
# [0, 1, 48, 121]
#
# Path from source to node 359
# [0, 1, 11, 30, 47]
#
# Path from source to node 360
# [0, 1, 44]
#
# Path from source to node 361
# [0, 1, 87]
#
# Path from source to node 362
# [0, 1, 11, 30, 44, 63]
#
# Path from source to node 363
# [0, 1, 44, 70, 250]
#
# Path from source to node 364
# [0, 1, 136]
#
# Path from source to node 365
# [0, 1, 47, 117, 125]
#
# Path from source to node 366
# [0, 1, 30, 47, 103]
#
# Path from source to node 367
# [0, 1, 47, 63, 68]
#
# Path from source to node 368
# [0, 1, 11, 30, 68, 412]
#
# Path from source to node 369
# [0, 1, 63, 101, 211]
#
# Path from source to node 370
# [0, 1, 11, 89]
#
# Path from source to node 371
# [0, 1, 68]
#
# Path from source to node 372
# [0, 1, 11, 68]
#
# Path from source to node 373
# [0, 1, 30, 44, 158]
#
# Path from source to node 374
# [0, 1, 47]
#
# Path from source to node 375
# [0, 1, 30, 130, 136]
#
# Path from source to node 376
# [0, 1, 30, 47, 48]
#
# Path from source to node 377
# [0, 1]
#
# Path from source to node 378
# [0, 1]
#
# Path from source to node 379
# [0, 1, 11]
#
# Path from source to node 380
# [0, 1]
#
# Path from source to node 381
# [0, 1, 11, 44, 48]
#
# Path from source to node 382
# [0, 1, 11, 70]
#
# Path from source to node 383
# [0, 1, 11, 122]
#
# Path from source to node 384
# [0, 1, 11, 44]
#
# Path from source to node 385
# [0, 1, 30, 87, 130]
#
# Path from source to node 386
# [0, 1, 30, 85, 125]
#
# Path from source to node 387
# [0, 1, 47, 85, 425]
#
# Path from source to node 388
# [0, 1]
#
# Path from source to node 389
# [0, 1, 11, 44, 72, 101]
#
# Path from source to node 390
# [0, 1, 121]
#
# Path from source to node 391
# [0, 1, 11, 70]
#
# Path from source to node 392
# [0, 1, 11, 87]
#
# Path from source to node 393
# [0, 1, 44, 47]
#
# Path from source to node 394
# [0, 1, 11, 72]
#
# Path from source to node 395
# [0, 1, 63]
#
# Path from source to node 396
# [0, 1, 11]
#
# Path from source to node 397
# [0, 1]
#
# Path from source to node 398
# [0, 1, 11]
#
# Path from source to node 399
# [0, 1, 11, 44, 70]
#
# Path from source to node 400
# [0, 1, 30, 48, 89]
#
# Path from source to node 401
# [0, 1, 11, 44, 194]
#
# Path from source to node 402
# [0, 1, 30, 103]
#
# Path from source to node 403
# [0, 1, 44, 239]
#
# Path from source to node 404
# [0, 1, 44]
#
# Path from source to node 405
# [0, 1, 11, 112]
#
# Path from source to node 406
# [0, 1, 30, 44, 48]
#
# Path from source to node 407
# [0, 1, 87]
#
# Path from source to node 408
# [0, 1]
#
# Path from source to node 409
# [0, 1]
#
# Path from source to node 410
# [0, 1]
#
# Path from source to node 411
# [0, 1, 30, 44, 112]
#
# Path from source to node 412
# [0, 1]
#
# Path from source to node 413
# [0, 1, 30, 68]
#
# Path from source to node 414
# [0, 1, 11, 48, 68]
#
# Path from source to node 415
# [0, 1, 11, 89]
#
# Path from source to node 416
# [0, 1, 11, 30, 44]
#
# Path from source to node 417
# [0, 1, 11, 47, 68]
#
# Path from source to node 418
# [0, 1, 101]
#
# Path from source to node 419
# [0, 1, 11]
#
# Path from source to node 420
# [0, 1]
#
# Path from source to node 421
# [0, 1]
#
# Path from source to node 422
# [0, 1, 63]
#
# Path from source to node 423
# [0, 1, 30, 147]
#
# Path from source to node 424
# [0, 1, 30, 44]
#
# Path from source to node 425
# [0, 1]
#
# Path from source to node 426
# [0, 1, 11, 72]
#
# Path from source to node 427
# [0, 1, 30, 44, 103]
#
# Path from source to node 428
# [0, 1, 11, 47, 112]
#
# Path from source to node 429
# [0, 1]
#
# Path from source to node 430
# [0, 1, 11, 44]
#
# Path from source to node 431
# [0, 1, 44]
#
# Path from source to node 432
# [0, 1, 11, 85, 305]
#
# Path from source to node 433
# [0, 1, 44, 48, 85]
#
# Path from source to node 434
# [0, 1, 47]
#
# Path from source to node 435
# [0, 1, 30, 47]
#
# Path from source to node 436
# [0, 1]
#
# Path from source to node 437
# [0, 1, 239]
#
# Path from source to node 438
# [0, 1, 30]
#
# Path from source to node 439
# [0, 1, 11, 44]
#
# Path from source to node 440
# [0, 1, 11, 125]
#
# Path from source to node 441
# [0, 1, 44, 136, 192]
#
# Path from source to node 442
# [0, 1, 30, 47, 89]
#
# Path from source to node 443
# [0, 1]
#
# Path from source to node 444
# [0, 1, 11, 47, 87]
#
# Path from source to node 445
# [0, 1, 11]
#
# Path from source to node 446
# [0, 1, 11]
#
# Path from source to node 447
# [0, 1]
#
# Path from source to node 448
# [0, 1, 44, 47, 48]
#
# Path from source to node 449
# [0, 1, 11, 68]
#
# Path from source to node 450
# [0, 1, 44, 47]
#
# Path from source to node 451
# [0, 1, 11, 30]
#
# Path from source to node 452
# [0, 1, 11, 101]
#
# Path from source to node 453
# [0, 1, 30, 48, 85]
#
# Path from source to node 454
# [0, 1, 44]
#
# Path from source to node 455
# [0, 1, 11]
#
# Path from source to node 456
# [0, 1, 11, 72]
#
# Path from source to node 457
# [0, 1, 44, 63]
#
# Path from source to node 458
# [0, 1, 48, 63]
#
# Path from source to node 459
# [0, 1, 11]
#
# Path from source to node 460
# [0, 1, 11, 63]
#
# Path from source to node 461
# [0, 1, 122]
#
# Path from source to node 462
# [0, 1, 85, 103]
#
# Path from source to node 463
# [0, 1, 11, 63]
#
# Path from source to node 464
# [0, 1, 30, 44, 125]
#
# Path from source to node 465
# [0, 1]
#
# Path from source to node 466
# [0, 1]
#
# Path from source to node 467
# [0, 1]
#
# Path from source to node 468
# [0, 1, 11, 48]
#
# Path from source to node 469
# [0, 1, 11]
#
# Path from source to node 470
# [0, 1, 11, 30, 63, 68]
#
# Path from source to node 471
# [0, 1, 11, 44, 90]
#
# Path from source to node 472
# [0, 1, 70]
#
# Path from source to node 473
# [0, 1, 44]
#
# Path from source to node 474
# [0, 1, 30, 85]
#
# Path from source to node 475
# [0, 1, 30, 48, 122]
#
# Path from source to node 476
# [0, 1, 11, 30, 47, 136]
#
# Path from source to node 477
# [0, 1, 11, 44, 85]
#
# Path from source to node 478
# [0, 1, 11, 68]
#
# Path from source to node 479
# [0, 1]
#
# Path from source to node 480
# [0, 1, 11, 44, 47, 48]
#
# Path from source to node 481
# [0, 1, 63]
#
# Path from source to node 482
# [0, 1, 11]
#
# Path from source to node 483
# [0, 1, 11, 30]
#
# Path from source to node 484
# [0, 1]
#
# Path from source to node 485
# [0, 1, 11, 63, 117, 136]
#
# Path from source to node 486
# [0, 1, 130]
#
# Path from source to node 487
# [0, 1, 11, 30, 44]
#
# Path from source to node 488
# [0, 1, 44, 47]
#
# Path from source to node 489
# [0, 1, 30, 48, 72, 112]
#
# Path from source to node 490
# [0, 1]
#
# Path from source to node 491
# [0, 1, 11, 30]
#
# Path from source to node 492
# [0, 1, 47]
#
# Path from source to node 493
# [0, 1]
#
# Path from source to node 494
# [0, 1, 44, 47]
#
# Path from source to node 495
# [0, 1, 11, 44, 68, 70, 103]
#
# Path from source to node 496
# [0, 1, 11, 72]
#
# Path from source to node 497
# [0, 1, 11, 30, 44, 68]
#
# Path from source to node 498
# [0, 1, 30, 47]
#
# Path from source to node 499
# [0, 1]
#
# Path from source to node 500
# [0, 1]
#
# Path from source to node 501
# [0, 1]
#
# Path from source to node 502
# [0, 1]
#
# Path from source to node 503
# [0, 1, 11]
#
# Path from source to node 504
# [0, 1, 11, 112]
#
# Path from source to node 505
# [0, 1]
# Path from source to node 506
# [0, 1]
#
# Path from source to node 507
# [0, 1, 11, 47]
#
# Path from source to node 508
# [0, 1]
#
# Path from source to node 509
# [0, 1, 11, 30]
#
# Path from source to node 510
# [0, 1]
#
# Path from source to node 511
# [0, 1, 11]
#
# Path from source to node 512
# [0, 1, 11]
#
# Path from source to node 513
# [0, 1]
#
# Path from source to node 514
# [0, 1, 68, 117]
#
# Path from source to node 515
# [0, 1, 11, 30, 44, 48]
#
# Path from source to node 516
# [0, 1, 11, 48, 134]
#
# Path from source to node 517
# [0, 1, 11, 47]
#
# Path from source to node 518
# [0, 1, 11, 85]
#
# Path from source to node 519
# [0, 1, 11, 30, 63, 72, 87]
#
# Path from source to node 520
# [0, 1, 44]
#
# Path from source to node 521
# [0, 1, 44]
#
# Path from source to node 522
# [0, 1, 63, 68]
#
# Path from source to node 523
# [0, 1, 11, 47]
#
# Path from source to node 524
# [0, 1, 47]
#
# Path from source to node 525
# [0, 1, 47]
#
# Path from source to node 526
# [0, 1, 70, 89]
#
# Path from source to node 527
# [0, 1, 136]
#
# Path from source to node 528
# [0, 1]
#
# Path from source to node 529
# [0, 1, 30, 89]
#
# Path from source to node 530
# [0, 1, 11]
#
# Path from source to node 531
# [0, 1]
#
# Path from source to node 532
# [0, 1, 11]
#
# Path from source to node 533
# [0, 1]
#
# Path from source to node 534
# [0, 1, 85, 87, 122, 136]
#
# Path from source to node 535
# [0, 1, 11, 44, 48, 239]
#
# Path from source to node 536
# [0, 1, 48]
#
# Path from source to node 537
# [0, 1, 11, 48]
#
# Path from source to node 538
# [0, 1, 11]
#
# Path from source to node 539
# [0, 1, 44]
#
# Path from source to node 540
# [0, 1, 47]
#
# Path from source to node 541
# [0, 1, 30]
#
# Path from source to node 542
# [0, 1]
#
# Path from source to node 543
# [0, 1, 11, 44]
#
# Path from source to node 544
# [0, 1]
#
# Path from source to node 545
# [0, 1, 48, 90]
#
# Path from source to node 546
# [0, 1, 11, 47, 48, 87, 136]
#
# Path from source to node 547
# [0, 1]
#
# Path from source to node 548
# [0, 1, 30]
#
# Path from source to node 549
# [0, 1, 30, 112]
#
# Path from source to node 550
# [0, 1, 11, 30, 500]
#
# Path from source to node 551
# [0, 1, 30, 68, 90]
#
# Path from source to node 552
# [0, 1, 11, 47]
#
# Path from source to node 553
# [0, 1, 44, 48, 63]
#
# ...
# [0, 1]
#
# Path from source to node 634
# [0, 1, 11, 44]
#
# Path from source to node 635
# [0, 1, 11, 44, 48]
#
# Path from source to node 636
# [0, 1, 11, 72]
#
# Path from source to node 637
# [0, 1, 11, 30, 48, 68, 136]
#
# Path from source to node 638
# [0, 1, 44, 70]
#
# Path from source to node 639
# [0, 1, 11, 122]
#
# Path from source to node 640
# [0, 1, 30]
#
# Path from source to node 641
# [0, 1, 44]
#
# Path from source to node 642
# [0, 1, 11, 121]
#
# Path from source to node 643
# [0, 1]
#
# Path from source to node 644
# [0, 1, 44, 48]
#
# Path from source to node 645
# [0, 1, 11, 87]
#
# Path from source to node 646
# [0, 1, 11]
#
# Path from source to node 647
# [0, 1]
#
# Path from source to node 648
# [0, 1, 11, 44]
#
# Path from source to node 649
# [0, 1, 112]
#
# Path from source to node 650
# [0, 1, 11, 47, 63]
#
# Path from source to node 651
# [0, 1, 44, 72]
#
# Path from source to node 652
# [0, 1, 11, 47]
#
# Path from source to node 653
# [0, 1, 44, 72, 85]
#
# Path from source to node 654
# [0, 1, 30, 44]
#
# Path from source to node 655
# [0, 1, 48, 63, 125]
#
# Path from source to node 656
# [0, 1, 11, 134]
#
# Path from source to node 657
# [0, 1, 68, 70]
#
# Path from source to node 658
# [0, 1]
#
# Path from source to node 659
# [0, 1, 68, 117]
#
# Path from source to node 660
# [0, 1]
#
# Path from source to node 661
# [0, 1, 44, 47]
#
# Path from source to node 662
# [0, 1, 11, 30, 48]
#
# Path from source to node 663
# [0, 1, 48]
#
# Path from source to node 664
# [0, 1, 11, 44, 103]
#
# Path from source to node 665
# [0, 1, 11]
#
# Path from source to node 666
# [0, 1, 11, 44, 192]
#
# Path from source to node 667
# [0, 1]
#
# Path from source to node 668
# [0, 1, 11]
#
# Path from source to node 669
# [0, 1, 68, 89]
#
# Path from source to node 670
# [0, 1, 11]
#
# Path from source to node 671
# [0, 1, 11]
#
# Path from source to node 672
# [0, 1]
#
# Path from source to node 673
# [0, 1, 48, 68]
#
# Path from source to node 674
# [0, 1, 47, 48]
#
# Path from source to node 675
# [0, 1, 11]
#
# Path from source to node 676
# [0, 1, 85, 121]
#
# Path from source to node 677
# [0, 1, 11]
#
# Path from source to node 678
# [0, 1, 30]
#
# Path from source to node 679
# [0, 1]
#
# Path from source to node 680
# [0, 1, 63]
#
# Path from source to node 681
# [0, 1, 44, 87]
#
# Path from source to node 682
# [0, 1, 11, 87]
#
# Path from source to node 683
# [0, 1, 47]
#
# Path from source to node 684
# [0, 1, 30]
#
# Path from source to node 685
# [0, 1, 11, 85, 101]
#
# Path from source to node 686
# [0, 1, 11, 85, 103]
#
# Path from source to node 687
# [0, 1, 30, 44, 87]
#
# Path from source to node 688
# [0, 1]
#
# Path from source to node 689
# [0, 1]
#
# Path from source to node 690
# [0, 1, 44, 70]
#
# Path from source to node 691
# [0, 1]
#
# Path from source to node 692
# [0, 1, 47]
#
# Path from source to node 693
# [0, 1, 63]
#
# Path from source to node 694
# [0, 1, 30]
#
# Path from source to node 695
# [0, 1, 48]
#
# Path from source to node 696
# [0, 1, 11]
#
# Path from source to node 697
# [0, 1, 68, 87]
#
# Path from source to node 698
# [0, 1, 44, 103]
#
# Path from source to node 699
# [0, 1, 30]
#
# Path from source to node 700
# [0, 1, 11, 68, 101]
#
# Path from source to node 701
# [0, 1, 30]
#
# Path from source to node 702
# [0, 1, 11, 44, 47]
#
# Path from source to node 703
# [0, 1]
#
# Path from source to node 704
# [0, 1, 11, 30]
#
# Path from source to node 705
# [0, 1]
#
# Path from source to node 706
# [0, 1]
#
# Path from source to node 707
# [0, 1]
#
# Path from source to node 708
# [0, 1, 490]
#
# Path from source to node 709
# [0, 1, 47, 48]
#
# Path from source to node 710
# [0, 1]
#
# Path from source to node 711
# [0, 1, 11]
#
# Path from source to node 712
# [0, 1]
#
# Path from source to node 713
# [0, 1, 70]
#
# Path from source to node 714
# [0, 1, 11, 48]
#
# Path from source to node 715
# [0, 1, 30]
#
# Path from source to node 716
# [0, 1]
#
# Path from source to node 717
# [0, 1, 30, 72]
#
# Path from source to node 718
# [0, 1, 30, 70]
#
# Path from source to node 719
# [0, 1, 44, 68]
#
# Path from source to node 720
# [0, 1]
#
# Path from source to node 721
# [0, 1, 11, 30, 47, 48]
#
# Path from source to node 722
# [0, 1]
#
# Path from source to node 723
# [0, 1, 11, 44]
#
# Path from source to node 724
# [0, 1, 30]
#
# Path from source to node 725
# [0, 1, 11]
#
# Path from source to node 726
# [0, 1]
#
# Path from source to node 727
# [0, 1]
#
# Path from source to node 728
# [0, 1, 11, 30, 44, 90]
#
# Path from source to node 729
# [0, 1, 11]
#
# Path from source to node 730
# [0, 1, 11, 30]
#
# Path from source to node 731
# [0, 1, 11, 63, 87]
#
# Path from source to node 732
# [0, 1, 30, 72]
#
# Path from source to node 733
# [0, 1, 47, 63, 101]
#
# Path from source to node 734
# [0, 1]
#
# Path from source to node 735
# [0, 1, 44, 89]
#
# Path from source to node 736
# [0, 1]
#
# Path from source to node 737
# [0, 1, 68]
#
# Path from source to node 738
# [0, 1]
#
# Path from source to node 739
# [0, 1]
#
# Path from source to node 740
# [0, 1]
#
# Path from source to node 741
# [0, 1]
#
# Path from source to node 742
# [0, 1, 11, 48]
#
# Path from source to node 743
# [0, 1, 11, 63]
#
# Path from source to node 744
# [0, 1, 30, 47, 48, 70, 136]
#
# Path from source to node 745
# [0, 1, 11, 63]
#
# Path from source to node 746
# [0, 1, 63]
#
# Path from source to node 747
# [0, 1]
#
# Path from source to node 748
# [0, 1, 11]
#
# Path from source to node 749
# [0, 1, 11, 85]
#
# Path from source to node 750
# [0, 1, 44, 103]
#
# Path from source to node 751
# [0, 1, 30, 63, 85]
#
# Path from source to node 752
# [0, 1, 11, 30]
#
# Path from source to node 753
# [0, 1, 30, 63, 89]
#
# Path from source to node 754
# [0, 1, 11, 70]
#
# Path from source to node 755
# [0, 1]
#
# Path from source to node 756
# [0, 1]
#
# Path from source to node 757
# [0, 1, 30, 44, 72]
#
# Path from source to node 758
# [0, 1, 11, 48]
#
# Path from source to node 759
# [0, 1, 63, 90]
#
# Path from source to node 760
# [0, 1, 30, 44, 47]
#
# Path from source to node 761
# [0, 1, 11, 70, 90]
#
# Path from source to node 762
# [0, 1, 11]
#
# Path from source to node 763
# [0, 1, 30, 48]
#
# Path from source to node 764
# [0, 1]
#
# Path from source to node 765
# [0, 1, 11, 44, 63, 70]
#
# Path from source to node 766
# [0, 1, 44, 70]
#
# Path from source to node 767
# [0, 1]
#
# Path from source to node 768
# [0, 1, 44, 47]
#
# Path from source to node 769
# [0, 1]
#
# Path from source to node 770
# [0, 1, 11, 70]
#
# Path from source to node 771
# [0, 1]
#
# Path from source to node 772
# [0, 1, 30]
#
# Path from source to node 773
# [0, 1, 11, 30, 101]
#
# Path from source to node 774
# [0, 1, 11, 30, 134]
#
# Path from source to node 775
# [0, 1]
#
# Path from source to node 776
# [0, 1]
#
# Path from source to node 777
# [0, 1, 11, 30, 44]
#
# Path from source to node 778
# [0, 1, 11, 30, 44]
#
# Path from source to node 779
# [0, 1, 11, 30, 89, 90]
#
# Path from source to node 780
# [0, 1, 30]
#
# Path from source to node 781
# [0, 1, 30, 44, 85, 239]
#
# Path from source to node 782
# [0, 1]
#
# Path from source to node 783
# [0, 1, 44, 87]
#
# Path from source to node 784
# [0, 1, 101]
#
# Path from source to node 785
# [0, 1]
#
# Path from source to node 786
# [0, 1, 30]
#
# Path from source to node 787
# [0, 1, 85]
#
# Path from source to node 788
# [0, 1, 44]
#
# Path from source to node 789
# [0, 1]
#
# Path from source to node 790
# [0, 1]
#
# Path from source to node 791
# [0, 1, 48]
#
# Path from source to node 792
# [0, 1, 47, 68, 87]
#
# Path from source to node 793
# [0, 1, 11, 44, 89]
#
# Path from source to node 794
# [0, 1, 30]
#
# Path from source to node 795
# [0, 1, 68]
#
# Path from source to node 796
# [0, 1]
#
# Path from source to node 797
# [0, 1]
#
# Path from source to node 798
# [0, 1]
#
# Path from source to node 799
# [0, 1, 11, 30, 44, 90]
#
# Path from source to node 800
# [0, 1, 11, 85, 425]
#
# Path from source to node 801
# [0, 1]
#
# Path from source to node 802
# [0, 1, 11, 134, 194]
#
# Path from source to node 803
# [0, 1, 11, 44, 48]
#
# Path from source to node 804
# [0, 1, 11]
#
# Path from source to node 805
# [0, 1, 11, 48]
#
# Path from source to node 806
# [0, 1, 11, 30, 68]
#
# Path from source to node 807
# [0, 1, 11, 44, 72]
#
# Path from source to node 808
# [0, 1, 30]
#
# Path from source to node 809
# [0, 1, 30]
#
# Path from source to node 810
# [0, 1, 30, 47]
#
# Path from source to node 811
# [0, 1, 11, 44]
#
# Path from source to node 812
# [0, 1, 44]
#
# Path from source to node 813
# [0, 1, 44, 136]
#
# Path from source to node 814
# [0, 1, 47, 63, 87]
#
# Path from source to node 815
# [0, 1, 30, 194]
#
# Path from source to node 816
# [0, 1, 47, 490]
#
# Path from source to node 817
# [0, 1, 11]
#
# Path from source to node 818
# [0, 1, 11, 44]
#
# Path from source to node 819
# [0, 1, 30, 47]
#
# Path from source to node 820
# [0, 1, 11, 47]
#
# Path from source to node 821
# [0, 1, 70]
#
# Path from source to node 822
# [0, 1, 11]
#
# Path from source to node 823
# [0, 1, 47, 68]
#
# Path from source to node 824
# [0, 1, 30, 89]
#
# Path from source to node 825
# [0, 1, 11, 68, 136]
#
# Path from source to node 826
# [0, 1]
#
# Path from source to node 827
# [0, 1, 11]
#
# Path from source to node 828
# [0, 1]
#
# Path from source to node 829
# [0, 1, 11, 103]
#
# Path from source to node 830
# [0, 1]
#
# Path from source to node 831
# [0, 1, 11, 44, 101]
#
# Path from source to node 832
# [0, 1, 11, 103]
#
# Path from source to node 833
# [0, 1, 11, 63, 305]
#
# Path from source to node 834
# [0, 1, 11, 68]
#
# Path from source to node 835
# [0, 1]
#
# Path from source to node 836
# [0, 1, 30, 44, 70]
#
# Path from source to node 837
# [0, 1, 70]
#
# Path from source to node 838
# [0, 1, 11, 44, 63]
#
# Path from source to node 839
# [0, 1]
#
# Path from source to node 840
# [0, 1, 11, 47]
#
# Path from source to node 841
# [0, 1, 90]
#
# Path from source to node 842
# [0, 1]
#
# Path from source to node 843
# [0, 1, 11, 30, 90]
#
# Path from source to node 844
# [0, 1]
#
# Path from source to node 845
# [0, 1, 103]
#
# Path from source to node 846
# [0, 1, 30, 85]
#
# Path from source to node 847
# [0, 1, 11, 68]
#
# Path from source to node 848
# [0, 1, 11, 112]
#
# Path from source to node 849
# [0, 1, 11, 30, 63]
#
# Path from source to node 850
# [0, 1, 47]
#
# Path from source to node 851
# [0, 1, 11, 30, 47]
#
# Path from source to node 852
# [0, 1, 11, 30]
#
# Path from source to node 853
# [0, 1, 11]
#
# Path from source to node 854
# [0, 1, 11, 30]
#
# Path from source to node 855
# [0, 1]
#
# Path from source to node 856
# [0, 1, 11]
#
# Path from source to node 857
# [0, 1, 44]
#
# Path from source to node 858
# [0, 1, 44, 48]
#
# Path from source to node 859
# [0, 1, 122]
#
# Path from source to node 860
# [0, 1, 11, 30, 63, 70]
#
# Path from source to node 861
# [0, 1, 30]
#
# Path from source to node 862
# [0, 1, 11, 44]
#
# Path from source to node 863
# [0, 1, 63, 101]
#
# Path from source to node 864
# [0, 1]
#
# Path from source to node 865
# [0, 1, 30, 44, 47]
#
# Path from source to node 866
# [0, 1, 30, 48, 691]
#
# Path from source to node 867
# [0, 1, 47, 48, 63]
#
# Path from source to node 868
# [0, 1, 63]
#
# Path from source to node 869
# [0, 1, 70]
#
# Path from source to node 870
# [0, 1, 70]
#
# Path from source to node 871
# [0, 1, 44, 47, 68]
#
# Path from source to node 872
# [0, 1, 63, 68]
#
# Path from source to node 873
# [0, 1, 11]
#
# Path from source to node 874
# [0, 1, 11, 30]
#
# Path from source to node 875
# [0, 1]
#
# Path from source to node 876
# [0, 1, 30, 44]
#
# Path from source to node 877
# [0, 1, 11, 72, 87, 117]
#
# Path from source to node 878
# [0, 1, 72]
#
# Path from source to node 879
# [0, 1, 11, 30, 44, 70]
#
# Path from source to node 880
# [0, 1, 11, 68, 125]
#
# Path from source to node 881
# [0, 1, 30, 87, 397]
#
# Path from source to node 882
# [0, 1, 44, 63]
#
# Path from source to node 883
# [0, 1, 11]
#
# Path from source to node 884
# [0, 1, 11, 48]
#
# Path from source to node 885
# [0, 1, 11, 122]
#
# Path from source to node 886
# [0, 1, 11, 63, 103, 136]
#
# Path from source to node 887
# [0, 1, 30, 44, 89]
#
# Path from source to node 888
# [0, 1, 30, 44]
#
# Path from source to node 889
# [0, 1, 44, 63, 89]
#
# Path from source to node 890
# [0, 1, 11, 44, 211]
#
# Path from source to node 891
# [0, 1, 11]
#
# Path from source to node 892
# [0, 1, 11, 30, 44]
#
# Path from source to node 893
# [0, 1, 11, 63, 70, 72]
#
# Path from source to node 894
# [0, 1, 30, 63, 163]
#
# Path from source to node 895
# [0, 1, 47, 68]
#
# Path from source to node 896
# [0, 1, 47]
#
# Path from source to node 897
# [0, 1, 11, 30, 68, 87]
#
# Path from source to node 898
# [0, 1, 11, 47]
#
# Path from source to node 899
# [0, 1, 44]
#
# Path from source to node 900
# [0, 1, 47, 68]
#
# Path from source to node 901
# [0, 1, 11, 68]
#
# Path from source to node 902
# [0, 1]
#
# Path from source to node 903
# [0, 1, 47, 87]
#
# Path from source to node 904
# [0, 1, 11, 30, 48]
#
# Path from source to node 905
# [0, 1, 47]
#
# Path from source to node 906
# [0, 1, 48]
#
# Path from source to node 907
# [0, 1, 63, 85]
#
# Path from source to node 908
# [0, 1, 11, 112, 163]
#
# Path from source to node 909
# [0, 1, 11, 30]
#
# Path from source to node 910
# [0, 1, 30]
#
# Path from source to node 911
# [0, 1]
#
# Path from source to node 912
# [0, 1, 11]
#
# Path from source to node 913
# [0, 1, 44, 63]
#
# Path from source to node 914
# [0, 1]
#
# Path from source to node 915
# [0, 1]
#
# Path from source to node 916
# [0, 1, 11, 48]
#
# Path from source to node 917
# [0, 1, 44]
#
# Path from source to node 918
# [0, 1, 72]
#
# Path from source to node 919
# [0, 1]
#
# Path from source to node 920
# [0, 1, 44]
#
# Path from source to node 921
# [0, 1, 70, 101, 134]
#
# Path from source to node 922
# [0, 1]
#
# Path from source to node 923
# [0, 1, 11, 30]
#
# Path from source to node 924
# [0, 1, 11, 30, 211]
#
# Path from source to node 925
# [0, 1, 30, 44]
#
# Path from source to node 926
# [0, 1]
#
# Path from source to node 927
# [0, 1, 11, 72]
#
# Path from source to node 928
# [0, 1, 30, 158]
#
# Path from source to node 929
# [0, 1, 72]
#
# Path from source to node 930
# [0, 1, 11, 44, 47]
#
# Path from source to node 931
# [0, 1, 48, 63, 87]
#
# Path from source to node 932
# [0, 1, 11, 48]
#
# Path from source to node 933
# [0, 1]
#
# Path from source to node 934
# [0, 1, 47, 211]
#
# Path from source to node 935
# [0, 1, 11]
#
# Path from source to node 936
# [0, 1]
#
# Path from source to node 937
# [0, 1, 11]
#
# Path from source to node 938
# [0, 1]
#
# Path from source to node 939
# [0, 1, 30, 72]
#
# Path from source to node 940
# [0, 1, 85]
#
# Path from source to node 941
# [0, 1, 89]
#
# Path from source to node 942
# [0, 1, 11, 30, 44, 68]
#
# Path from source to node 943
# [0, 1, 47, 48, 63]
#
# Path from source to node 944
# [0, 1, 70]
#
# Path from source to node 945
# [0, 1, 30]
#
# Path from source to node 946
# [0, 1, 30, 103]
#
# Path from source to node 947
# [0, 1, 30, 130]
#
# Path from source to node 948
# [0, 1, 11, 87]
#
# Path from source to node 949
# [0, 1]
#
# Path from source to node 950
# [0, 1, 30]
#
# Path from source to node 951
# [0, 1, 11]
#
# Path from source to node 952
# [0, 1, 11]
#
# Path from source to node 953
# [0, 1]
#
# Path from source to node 954
# [0, 1, 11, 30, 103, 292]
#
# Path from source to node 955
# [0, 1, 11, 70]
#
# Path from source to node 956
# [0, 1, 87, 122]
#
# Path from source to node 957
# [0, 1, 48, 87]
#
# Path from source to node 958
# [0, 1, 44]
#
# Path from source to node 959
# [0, 1, 30, 112]
#
# Path from source to node 960
# [0, 1]
#
# Path from source to node 961
# [0, 1, 11, 30, 47, 163]
#
# Path from source to node 962
# [0, 1, 11, 44]
#
# Path from source to node 963
# [0, 1]
#
# Path from source to node 964
# [0, 1, 44, 230]
#
# Path from source to node 965
# [0, 1, 11]
#
# Path from source to node 966
# [0, 1, 11, 103]
#
# Path from source to node 967
# [0, 1, 11, 44, 68]
#
# Path from source to node 968
# [0, 1, 11, 48]
#
# Path from source to node 969
# [0, 1, 48]
#
# Path from source to node 970
# [0, 1, 11, 87]
#
# Path from source to node 971
# [0, 1, 101]
#
# Path from source to node 972
# [0, 1, 44, 47, 48]
#
# Path from source to node 973
# [0, 1, 11, 63]
#
# Path from source to node 974
# [0, 1]
#
# Path from source to node 975
# [0, 1, 30]
#
# Path from source to node 976
# [0, 1, 44, 47]
#
# Path from source to node 977
# [0, 1, 44, 117, 134]
#
# Path from source to node 978
# [0, 1, 11]
#
# Path from source to node 979
# [0, 1, 11, 44, 47, 87]
#
# Path from source to node 980
# [0, 1, 101]
#
# Path from source to node 981
# [0, 1, 11]
#
# Path from source to node 982
# [0, 1, 30, 68]
#
# Path from source to node 983
# [0, 1, 44]
#
# Path from source to node 984
# [0, 1, 63, 70]
#
# Path from source to node 985
# [0, 1]
#
# Path from source to node 986
# [0, 1]
#
# Path from source to node 987
# [0, 1]
#
# Path from source to node 988
# [0, 1, 48, 89]
#
# Path from source to node 989
# [0, 1, 63]
#
# Path from source to node 990
# [0, 1, 48]
#
# Path from source to node 991
# [0, 1, 44, 89]
#
# Path from source to node 992
# [0, 1, 47]
#
# Path from source to node 993
# [0, 1]
#
# Path from source to node 994
# [0, 1, 30]
#
# Path from source to node 995
# [0, 1, 44, 48, 112, 122]
#
# Path from source to node 996
# [0, 1, 11]
#
# Path from source to node 997
# [0, 1, 48, 121, 122]
#
# Path from source to node 998
# [0, 1, 11, 30, 47, 72, 85]
#
# Path from source to node 999
# [0, 1]

# %% [markdown]
# Part (b) - Implementation of Dijkstra's algorithm using adjacency list + min heap as priority queue
#
# For this implementation, we shall use the heapq module for our min heap.

# %%
def DijkstraB(G, source):
    time_start = timeit.default_timer()
    
    distance = [sys.maxsize] * G.V  # Original distance for all vertices are set to infinity
    path = [[] for i in range(G.V)]  # Initialize N number of sub-lists to store the path to each node
    S = [False] * G.V  # Initialize False to all the nodes since shortest path not yet discovered

    distance[source] = 0  # Set distance of source node to be zero
    
    minHeap = []
    for i in range(G.V):  # Insert all the vertices into min heap
        heapq.heappush(minHeap, [distance[i], i])
    
    while (len(minHeap) != 0):
        u = heapq.heappop(minHeap)
        S[u[1]] = True
        
        for elements in G.listgraph[u[1]]:
            if S[elements[0]] != True and distance[elements[0]] > distance[u[1]] + elements[1]:
                for z in minHeap:
                    if z[1] == elements[0]:
                        minHeap.remove(z)
                        heapq.heapify(minHeap)
                            
                distance[elements[0]] = distance[u[1]] + elements[1]
                    
                if source not in path[elements[0]]:
                    for nodes in path[u[1]]:
                        path[elements[0]].append(nodes)
                path[elements[0]].append(u[1])
                    
                heapq.heappush(minHeap, [distance[elements[0]], elements[0]])
    
    time_stop = timeit.default_timer()
    #END OF DIJKSTRA ALGORITHM
    
    #Print results
    print("Time elapsed for program: ", (time_stop - time_start)*1000, "milliseconds")  # Time in milliseconds
    print("Distance from source node,")
    for i in range(0, G.V):
        if distance[i] == sys.maxsize:
            print("Source to node", i, ": No such path exist")
        else:
            print("Source to node", i, ":", distance[i])
        resultB.append(distance[i])
    
    print()
    print("Path to get to each node,")
    
    for i in range(0, G.V):
        print("Path from source to node", i)
        print(path[i])
        print()

# %%
DijkstraB(g, 0)
# Out:
# Time elapsed for program:  2282.3397000000227 milliseconds
# Distance from source node,
# Source to node 0 : 0
# Source to node 1 : 8
# Source to node 2 : 10
# Source to node 3 : 10
# Source to node 4 : 10
# Source to node 5 : 10
# Source to node 6 : 10
# Source to node 7 : 10
# Source to node 8 : 10
# Source to node 9 : 10
# Source to node 10 : 10
# Source to node 11 : 9
# Source to node 12 : 10
# Source to node 13 : 10
# Source to node 14 : 10
# Source to node 15 : 10
# Source to node 16 : 10
# Source to node 17 : 10
# Source to node 18 : 10
# Source to node 19 : 10
# Source to node 20 : 10
# Source to node 21 : 10
# Source to node 22 : 10
# Source to node 23 : 10
# Source to node 24 : 10
# Source to node 25 : 10
# Source to node 26 : 10
# Source to node 27 : 10
# Source to node 28 : 10
# Source to node 29 : 10
# Source to node 30 : 9
# Source to node 31 : 10
# Source to node 32 : 10
# Source to node 33 : 10
# Source to node 34 : 10
# Source to node 35 : 10
# Source to node 36 : 10
# Source to node 37 : 10
# Source to node 38 : 10
# Source to node 39 : 10
# Source to node 40 : 10
# Source to node 41 : 10
# Source to node 42 : 10
# Source to node 43 : 10
# Source to node 44 : 9
# Source to node 45 : 10
# Source to node 46 : 10
# Source to node 47 : 9
# Source to node 48 : 9
# Source to node 49 : 10
# Source to node 50 : 10
# Source to node 51 : 10
# Source to node 52 : 10
# Source to node 53 : 10
# Source to node 54 : 10
# Source to node 55 : 10
# Source to node 56 : 10
# Source to node 57 : 10
# Source to node 58 : 10
# Source to node 59 : 10
# Source to node 60 : 10
# Source to node 61 : 10
# Source to node 62 : 10
# Source to node 63 : 9
# Source to node 64 : 10
# Source to node 65 : 10
# Source to node 66 : 10
# Source to node 67 : 10
# Source to node 68 : 9
# Source to node 69 : 10
# Source to node 70 : 9
# Source to node 71 : 10
# Source to node 72 : 9
# Source to node 73 : 10
# Source to node 74 : 10
# Source to node 75 : 10
# Source to node 76 : 10
# Source to node 77 : 10
# Source to node 78 : 10
# Source to node 79 : 10
# Source to node 80 : 10
# Source to node 81 : 10
# Source to node 82 : 10
# Source to node 83 : 10
# Source to node 84 : 10
# Source to node 85 : 9
# Source to node 86 : 10
# Source to node 87 : 9
# Source to node 88 : 10
# Source to node 89 : 9
# Source to node 90 : 9
# Source to node 91 : 10
# Source to node 92 : 10
# Source to node 93 : 10
# Source to node 94 : 10
# Source to node 95 : 10
# Source to node 96 : 10
# Source to node 97 : 10
# Source to node 98 : 10
# Source to node 99 : 10
# Source to node 100 : 10
# Source to node 101 : 9
# Source to node 102 : 10
# Source to node 103 : 9
# Source to node 104 : 10
# Source to node 105 : 10
# Source to node 106 : 10
# Source to node 107 : 10
# Source to node 108 : 10
# Source to node 109 : 10
# Source to node 110 : 10
# Source to node 111 : 10
# Source to node 112 : 9
# Source to node 113 : 10
# Source to node 114 : 10
# Source to node 115 : 10
# Source to node 116 : 10
# Source to node 117 : 9
# Source to node 118 : 10
# Source to node 119 : 10
# Source to node 120 : 10
# Source to node 121 : 9
# Source to node 122 : 9
# Source to node 123 : 10
# Source to node 124 : 10
# Source to node 125 : 9
# Source to node 126 : 10
# Source to node 127 : 10
# Source to node 128 : 10
# Source to node 129 : 10
# Source to node 130 : 9
# Source to node 131 : 10
# Source to node 132 : 10
# Source to node 133 : 10
# Source to node 134 : 9
# Source to node 135 : 10
# Source to node 136 : 9
# Source to node 137 : 10
# Source to node 138 : 10
# Source to node 139 : 10
# Source to node 140 : 10
# Source to node 141 : 10
# Source to node 142 : 10
# Source to node 143 : 10
# Source to node 144 : 10
# Source to node 145 : 10
# Source to node 146 : 10
# Source to node 147 : 9
# Source to node 148 : 10
# Source to node 149 : 10
# Source to node 150 : 10
# Source to node 151 : 10
# Source to node 152 : 10
# Source to node 153 : 10
# Source to node 154 : 10
# Source to node 155 : 10
# Source to node 156 : 10
# Source to node 157 : 10
# Source to node 158 : 9
# Source to node 159 : 10
# Source to node 160 : 10
# Source to node 161 : 10
# Source to node 162 : 10
# Source to node 163 : 9
# Source to node 164 : 10
# Source to node 165 : 10
# Source to node 166 : 10
# Source to node 167 : 10
# Source to node 168 : 10
# Source to node 169 : 10
# Source to node 170 : 9
# Source to node 171 : 10
# Source to node 172 : 10
# Source to node 173 : 10
# Source to node 174 : 10
# Source to node 175 : 10
# Source to node 176 : 10
# Source to node 177 : 10
# Source to node 178 : 10
# Source to node 179 : 10
# Source to node 180 : 10
# Source to node 181 : 10
# Source to node 182 : 10
# Source to node 183 : 10
# Source to node 184 : 10
# Source to node 185 : 10
# Source to node 186 : 10
# Source to node 187 : 10
# Source to node 188 : 10
# Source to node 189 : 10
# Source to node 190 : 10
# Source to node 191 : 10
# Source to node 192 : 9
# Source to node 193 : 10
# Source to node 194 : 9
# Source to node 195 : 10
# Source to node 196 : 10
# Source to node 197 : 10
# Source to node 198 : 10
# Source to node 199 : 10
# Source to node 200 : 10
# Source to node 201 : 10
# Source to node 202 : 10
# Source to node 203 : 10
# Source to node 204 : 10
# Source to node 205 : 10
# Source to node 206 : 10
# Source to node 207 : 10
# Source to node 208 : 10
# Source to node 209 : 10
# Source to node 210 : 10
# Source to node 211 : 9
# Source to node 212 : 10
# Source to node 213 : 10
# Source to node 214 : 10
# Source to node 215 : 10
# Source to node 216 : 10
# Source to node 217 : 10
# Source to node 218 : 10
# Source to node 219 : 10
# Source to node 220 : 10
# Source to node 221 : 10
# Source to node 222 : 10
# Source to node 223 : 10
# Source to node 224 : 10
# Source to node 225 : 10
# Source to node 226 : 10
# Source to node 227 : 10
# Source to node 228 : 10
# Source to node 229 : 10
# Source to node 230 : 9
# Source to node 231 : 10
# Source to node 232 : 10
# Source to node 233 : 10
# Source to node 234 : 10
# Source to node 235 : 10
# Source to node 236 : 10
# Source to node 237 : 10
# Source to node 238 : 10
# Source to node 239 : 9
# Source to node 240 : 10
# Source to node 241 : 10
# Source to node 242 : 10
# Source to node 243 : 10
# Source to node 244 : 10
# Source to node 245 : 10
# Source to node 246 : 10
# Source to node 247 : 10
# Source to node 248 : 10
# Source to node 249 : 10
# Source to node 250 : 9
# Source to node 251 : 10
# Source to node 252 : 10
# Source to node 253 : 10
# Source to node 254 : 10
# Source to node 255 : 10
# Source to node 256 : 10
# Source to node 257 : 10
# Source to node 258 : 10
# Source to node 259 : 10
# Source to node 260 : 10
# Source to node 261 : 10
# Source to node 262 : 10
# Source to node 263 : 10
# Source to node 264 : 10
# Source to node 265 : 10
# Source to node 266 : 10
# Source to node 267 : 10
# Source to node 268 : 10
# Source to node 269 : 10
# Source to node 270 : 10
# Source to node 271 : 10
# Source to node 272 : 10
# Source to node 273 : 10
# Source to node 274 : 10
# Source to node 275 : 10
# Source to node 276 : 10
# Source to node 277 : 10
# Source to node 278 : 10
# Source to node 279 : 10
# Source to node 280 : 10
# Source to node 281 : 10
# Source to node 282 : 10
# Source to node 283 : 10
# Source to node 284 : 10
# Source to node 285 : 10
# Source to node 286 : 10
# Source to node 287 : 10
# Source to node 288 : 10
# Source to node 289 : 10
# Source to node 290 : 10
# Source to node 291 : 9
# Source to node 292 : 9
# Source to node 293 : 10
# Source to node 294 : 10
# Source to node 295 : 10
# Source to node 296 : 10
# Source to node 297 : 10
# Source to node 298 : 10
# Source to node 299 : 10
# Source to node 300 : 10
# Source to node 301 : 10
# Source to node 302 : 10
# Source to node 303 : 10
# Source to node 304 : 10
# Source to node 305 : 9
# Source to node 306 : 10
# Source to node 307 : 10
# Source to node 308 : 10
# Source to node 309 : 10
# Source to node 310 : 10
# Source to node 311 : 10
# Source to node 312 : 10
# Source to node 313 : 10
# Source to node 314 : 10
# Source to node 315 : 10
# Source to node 316 : 9
# Source to node 317 : 10
# Source to node 318 : 10
# Source to node 319 : 10
# Source to node 320 : 10
# Source to node 321 : 10
# Source to node 322 : 10
# Source to node 323 : 10
# Source to node 324 : 10
# Source to node 325 : 10
# Source to node 326 : 10
# Source to node 327 : 10
# Source to node 328 : 9
# Source to node 329 : 10
# Source to node 330 : 10
# Source to node 331 : 10
# Source to node 332 : 9
# Source to node 333 : 10
# Source to node 334 : 10
# Source to node 335 : 10
# Source to node 336 : 9
# Source to node 337 : 10
# Source to node 338 : 10
# Source to node 339 : 10
# Source to node 340 : 10
# Source to node 341 : 9
# Source to node 342 : 10
# Source to node 343 : 10
# Source to node 344 : 10
# Source to node 345 : 10
# Source to node 346 : 9
# Source to node 347 : 9
# Source to node 348 : 10
# Source to node 349 : 10
# Source to node 350 : 10
# Source to node 351 : 10
# Source to node 352 : 10
# Source to node 353 : 10
# Source to node 354 : 10
# Source to node 355 : 10
# Source to node 356 : 10
# Source to node 357 : 10
# Source to node 358 : 10
# Source to node 359 : 10
# Source to node 360 : 10
# Source to node 361 : 10
# Source to node 362 : 10
# Source to node 363 : 10
# Source to node 364 : 10
# Source to node 365 : 10
# Source to node 366 : 10
# Source to node 367 : 10
# Source to node 368 : 10
# Source to node 369 : 10
# Source to node 370 : 10
# Source to node 371 : 10
# Source to node 372 : 10
# Source to node 373 : 10
# Source to node 374 : 10
# Source to node 375 : 10
# Source to node 376 : 10
# Source to node 377 : 10
# Source to node 378 : 10
# Source to node 379 : 10
# Source to node 380 : 10
# Source to node 381 : 10
# Source to node 382 : 10
# Source to node 383 : 10
# Source to node 384 : 10
# Source to node 385 : 10
# Source to node 386 : 10
# Source to node 387 : 10
# Source to node 388 : 10
# Source to node 389 : 10
# Source to node 390 : 10
# Source to node 391 : 10
# Source to node 392 : 10
# Source to node 393 : 10
# Source to node 394 : 10
# Source to node 395 : 10
# Source to node 396 : 10
# Source to node 397 : 9
# Source to node 398 : 10
# Source to node 399 : 10
# Source to node 400 : 10
# Source to node 401 : 10
# Source to node 402 : 10
# Source to node 403 : 10
# Source to node 404 : 10
# Source to node 405 : 10
# Source to node 406 : 10
# Source to node 407 : 10
# Source to node 408 : 10
# Source to node 409 : 10
# Source to node 410 : 9
# Source to node 411 : 10
# Source to node 412 : 9
# Source to node 413 : 10
# Source to node 414 : 10
# Source to node 415 : 10
# Source to node 416 : 10
# Source to node 417 : 10
# Source to node 418 : 10
# Source to node 419 : 10
# Source to node 420 : 9
# Source to node 421 : 10
# Source to node 422 : 10
# Source to node 423 : 10
# Source to node 424 : 10
# Source to node 425 : 9
# Source to node 426 : 10
# Source to node 427 : 10
# Source to node 428 : 10
# Source to node 429 : 9
# Source to node 430 : 10
# Source to node 431 : 10
# Source to node 432 : 10
# Source to node 433 : 10
# Source to node 434 : 10
# Source to node 435 : 10
# Source to node 436 : 10
# Source to node 437 : 10
# Source to node 438 : 10
# Source to node 439 : 10
# Source to node 440 : 10
# Source to node 441 : 10
# Source to node 442 : 10
# Source to node 443 : 10
# Source to node 444 : 10
# Source to node 445 : 10
# Source to node 446 : 10
# Source to node 447 : 10
# Source to node 448 : 10
# Source to node 449 : 10
# Source to node 450 : 10
# Source to node 451 : 10
# Source to node 452 : 10
# Source to node 453 : 10
# Source to node 454 : 10
# Source to node 455 : 10
# Source to node 456 : 10
# Source to node 457 : 10
# Source to node 458 : 10
# Source to node 459 : 10
# Source to node 460 : 10
# Source to node 461 : 10
# Source to node 462 : 10
# Source to node 463 : 10
# Source to node 464 : 10
# Source to node 465 : 10
# Source to node 466 : 9
# Source to node 467 : 10
# Source to node 468 : 10
# Source to node 469 : 10
# Source to node 470 : 10
# Source to node 471 : 10
# Source to node 472 : 10
# Source to node 473 : 10
# Source to node 474 : 10
# Source to node 475 : 10
# Source to node 476 : 10
# Source to node 477 : 10
# Source to node 478 : 10
# Source to node 479 : 9
# Source to node 480 : 10
# Source to node 481 : 10
# Source to node 482 : 10
# Source to node 483 : 10
# Source to node 484 : 10
# Source to node 485 : 10
# Source to node 486 : 10
# Source to node 487 : 10
# Source to node 488 : 10
# Source to node 489 : 10
# Source to node 490 : 9
# Source to node 491 : 10
# Source to node 492 : 10
# Source to node 493 : 10
# Source to node 494 : 10
# Source to node 495 : 10
# Source to node 496 : 10
# Source to node 497 : 10
# Source to node 498 : 10
# Source to node 499 : 10
# Source to node 500 : 9
# Source to node 501 : 9
# Source to node 502 : 9
# Source to node 503 : 10
# Source to node 504 : 10
# Source to node 505 : 9
# Source to node 506 : 10
# Source to node 507 : 10
# Source to node 508 : 10
# Source to node 509 : 10
# Source to node 510 : 9
# Source to node 511 : 10
# Source to node 512 : 10
# Source to node 513 : 9
# Source to node 514 : 10
# Source to node 515 : 10
# Source to node 516 : 10
# Source to node 517 : 10
# Source to node 518 : 10
# Source to node 519 : 10
# Source to node 520 : 10
# Source to node 521 : 10
# Source to node 522 : 10
# Source to node 523 : 10
# Source to node 524 : 10
# Source to node 525 : 10
# Source to node 526 : 10
# Source to node 527 : 10
# Source to node 528 : 9
# Source to node 529 : 10
# Source to node 530 : 10
# Source to node 531 : 9
# Source to node 532 : 10
# Source to node 533 : 10
# Source to node 534 : 10
# Source to node 535 : 10
# Source to node 536 : 10
# Source to node 537 : 10
# Source to node 538 : 10
# Source to node 539 : 10
# Source to node 540 : 10
# Source to node 541 : 10
# Source to node 542 : 9
# Source to node 543 : 10
# Source to node 544 : 10
# Source to node 545 : 10
# Source to node 546 : 10
# Source to node 547 : 10
# Source to node 548 : 10
# Source to node 549 : 10
# Source to node 550 : 10
# Source to node 551 : 10
# Source to node 552 : 10
# Source to node 553 : 10
# Source to node 554 : 10
# Source to node 555 : 10
# Source to node 556 : 10
# Source to node 557 : 10
# Source to node 558 : 10
# Source to node 559 : 10
# Source to node 560 : 10
# Source to node 561 : 10
# Source to node 562 : 10
# Source to node 563 : 10
# Source to node 564 : 10
# Source to node 565 : 10
# Source to node 566 : 10
# Source to node 567 : 10
# Source to node 568 : 10
# Source to node 569 : 9
# Source to node 570 : 10
# Source to node 571 : 10
# Source to node 572 : 10
# Source to node 573 : 10
# Source to node 574 : 10
# Source to node 575 : 10
# Source to node 576 : 10
# Source to node 577 : 10
# Source to node 578 : 10
# Source to node 579 : 10
# Source to node 580 : 10
# Source to node 581 : 10
# Source to node 582 : 10
# Source to node 583 : 9
# Source to node 584 : 10
# Source to node 585 : 10
# Source to node 586 : 10
# Source to node 587 : 10
# Source to node 588 : 10
# Source to node 589 : 10
# Source to node 590 : 10
# Source to node 591 : 10
# Source to node 592 : 10
# Source to node 593 : 9
# Source to node 594 : 10
# Source to node 595 : 10
# Source to node 596 : 10
# Source to node 597 : 10
# Source to node 598 : 10
# Source to node 599 : 10
# Source to node 600 : 10
# Source to node 601 : 10
# Source to node 602 : 10
# Source to node 603 : 10
# Source to node 604 : 10
# Source to node 605 : 10
# Source to node 606 : 10
# Source to node 607 : 10
# Source to node 608 : 10
# Source to node 609 : 10
# Source to node 610 : 10
# Source to node 611 : 10
# Source to node 612 : 10
# Source to node 613 : 10
# Source to node 614 : 10
# Source to node 615 : 10
# Source to node 616 : 10
# Source to node 617 : 10
# Source to node 618 : 10
# Source to node 619 : 10
# Source to node 620 : 10
# Source to node 621 : 10
# Source to node 622 : 10
# Source to node 623 : 10
# Source to node 624 : 10
# Source to node 625 : 10
# Source to node 626 : 10
# Source to node 627 : 10
# Source to node 628 : 10
# Source to node 629 : 10
# Source to node 630 : 10
# Source to node 631 : 10
# Source to node 632 : 10
# Source to node 633 : 9
# Source to node 634 : 10
# Source to node 635 : 10
# Source to node 636 : 10
# Source to node 637 : 10
# Source to node 638 : 10
# Source to node 639 : 10
# Source to node 640 : 10
# Source to node 641 : 10
# Source to node 642 : 10
# Source to node 643 : 10
# Source to node 644 : 10
# Source to node 645 : 10
# Source to node 646 : 10
# Source to node 647 : 10
# Source to node 648 : 10
# Source to node 649 : 10
# Source to node 650 : 10
# Source to node 651 : 10
# Source to node 652 : 10
# Source to node 653 : 10
# Source to node 654 : 10
# Source to node 655 : 10
# Source to node 656 : 10
# Source to node 657 : 10
# Source to node 658 : 10
# Source to node 659 : 10
# Source to node 660 : 9
# Source to node 661 : 10
# Source to node 662 : 10
# Source to node 663 : 10
# Source to node 664 : 10
# Source to node 665 : 10
# Source to node 666 : 10
# Source to node 667 : 9
# Source to node 668 : 10
# Source to node 669 : 10
# Source to node 670 : 10
# Source to node 671 : 10
# Source to node 672 : 9
# Source to node 673 : 10
# Source to node 674 : 10
# Source to node 675 : 10
# Source to node 676 : 10
# Source to node 677 : 10
# Source to node 678 : 10
# Source to node 679 : 10
# Source to node 680 : 10
# Source to node 681 : 10
# Source to node 682 : 10
# Source to node 683 : 10
# Source to node 684 : 10
# Source to node 685 : 10
# Source to node 686 : 10
# Source to node 687 : 10
# Source to node 688 : 10
# Source to node 689 : 10
# Source to node 690 : 10
# Source to node 691 : 9
# Source to node 692 : 10
# Source to node 693 : 10
# Source to node 694 : 10
# Source to node 695 : 10
# Source to node 696 : 10
# Source to node 697 : 10
# Source to node 698 : 10
# Source to node 699 : 10
# Source to node 700 : 10
# Source to node 701 : 10
# Source to node 702 : 10
# Source to node 703 : 10
# Source to node 704 : 10
# Source to node 705 : 10
# Source to node 706 : 9
# Source to node 707 : 9
# Source to node 708 : 10
# Source to node 709 : 10
# Source to node 710 : 9
# Source to node 711 : 10
# Source to node 712 : 10
# Source to node 713 : 10
# Source to node 714 : 10
# Source to node 715 : 10
# Source to node 716 : 9
# Source to node 717 : 10
# Source to node 718 : 10
# Source to node 719 : 10
# Source to node 720 : 10
# Source to node 721 : 10
# Source to node 722 : 9
# Source to node 723 : 10
# Source to node 724 : 10
# Source to node 725 : 10
# Source to node 726 : 10
# Source to node 727 : 9
# Source to node 728 : 10
# Source to node 729 : 10
# Source to node 730 : 10
# Source to node 731 : 10
# Source to node 732 : 10
# Source to node 733 : 10
# Source to node 734 : 9
# Source to node 735 : 10
# Source to node 736 : 9
# Source to node 737 : 10
# Source to node 738 : 9
# Source to node 739 : 9
# Source to node 740 : 9
# Source to node 741 : 9
# Source to node 742 : 10
# Source to node 743 : 10
# Source to node 744 : 10
# Source to node 745 : 10
# Source to node 746 : 10
# Source to node 747 : 9
# Source to node 748 : 10
# Source to node 749 : 10
# Source to node 750 : 10
# Source to node 751 : 10
# Source to node 752 : 10
# Source to node 753 : 10
# Source to node 754 : 10
# Source to node 755 : 10
# Source to node 756 : 9
# Source to node 757 : 10
# Source to node 758 : 10
# Source to node 759 : 10
# Source to node 760 : 10
# Source to node 761 : 10
# Source to node 762 : 10
# Source to node 763 : 10
# Source to node 764 : 10
# Source to node 765 : 10
# Source to node 766 : 10
# Source to node 767 : 10
# Source to node 768 : 10
# Source to node 769 : 10
# Source to node 770 : 10
# Source to node 771 : 10
# Source to node 772 : 10
# Source to node 773 : 10
# Source to node 774 : 10
# Source to node 775 : 9
# Source to node 776 : 10
# Source to node 777 : 10
# Source to node 778 : 10
# Source to node 779 : 10
# Source to node 780 : 10
# Source to node 781 : 10
# Source to node 782 : 9
# Source to node 783 : 10
# Source to node 784 : 10
# Source to node 785 : 9
# Source to node 786 : 10
# Source to node 787 : 10
# Source to node 788 : 10
# Source to node 789 : 9
# Source to node 790 : 10
# Source to node 791 : 10
# Source to node 792 : 10
# Source to node 793 : 10
# Source to node 794 : 10
# Source to node 795 : 10
# Source to node 796 : 9
# Source to node 797 : 10
# Source to node 798 : 9
# Source to node 799 : 10
# Source to node 800 : 10
# Source to node 801 : 9
# Source to node 802 : 10
# Source to node 803 : 10
# Source to node 804 : 10
# Source to node 805 : 10
# Source to node 806 : 10
# Source to node 807 : 10
# Source to node 808 : 10
# Source to node 809 : 10
# Source to node 810 : 10
# Source to node 811 : 10
# Source to node 812 : 10
# Source to node 813 : 10
# Source to node 814 : 10
# Source to node 815 : 10
# Source to node 816 : 10
# Source to node 817 : 10
# Source to node 818 : 10
# Source to node 819 : 10
# Source to node 820 : 10
# Source to node 821 : 10
# Source to node 822 : 10
# Source to node 823 : 10
# Source to node 824 : 10
# Source to node 825 : 10
# Source to node 826 : 9
# Source to node 827 : 10
# Source to node 828 : 10
# Source to node 829 : 10
# Source to node 830 : 9
# Source to node 831 : 10
# Source to node 832 : 10
# Source to node 833 : 10
# Source to node 834 : 10
# Source to node 835 : 9
# Source to node 836 : 10
# Source to node 837 : 10
# Source to node 838 : 10
# Source to node 839 : 10
# Source to node 840 : 10
# Source to node 841 : 10
# Source to node 842 : 9
# Source to node 843 : 10
# Source to node 844 : 9
# Source to node 845 : 10
# Source to node 846 : 10
# Source to node 847 : 10
# Source to node 848 : 10
# Source to node 849 : 10
# Source to node 850 : 10
# Source to node 851 : 10
# Source to node 852 : 10
# Source to node 853 : 10
# Source to node 854 : 10
# Source to node 855 : 10
# Source to node 856 : 10
# Source to node 857 : 10
# Source to node 858 : 10
# Source to node 859 : 10
# Source to node 860 : 10
# Source to node 861 : 10
# Source to node 862 : 10
# Source to node 863 : 10
# Source to node 864 : 10
# Source to node 865 : 10
# Source to node 866 : 10
# Source to node 867 : 10
# Source to node 868 : 10
# Source to node 869 : 10
# Source to node 870 : 10
# Source to node 871 : 10
# Source to node 872 : 10
# Source to node 873 : 10
# Source to node 874 : 10
# Source to node 875 : 9
# Source to node 876 : 10
# Source to node 877 : 10
# Source to node 878 : 10
# Source to node 879 : 10
# Source to node 880 : 10
# Source to node 881 : 10
# Source to node 882 : 10
# Source to node 883 : 10
# Source to node 884 : 10
# Source to node 885 : 10
# Source to node 886 : 10
# Source to node 887 : 10
# Source to node 888 : 10
# Source to node 889 : 10
# Source to node 890 : 10
# Source to node 891 : 10
# Source to node 892 : 10
# Source to node 893 : 10
# Source to node 894 : 10
# Source to node 895 : 10
# Source to node 896 : 10
# Source to node 897 : 10
# Source to node 898 : 10
# Source to node 899 : 10
# Source to node 900 : 10
# Source to node 901 : 10
# Source to node 902 : 10
# Source to node 903 : 10
# Source to node 904 : 10
# Source to node 905 : 10
# Source to node 906 : 10
# Source to node 907 : 10
# Source to node 908 : 10
# Source to node 909 : 10
# Source to node 910 : 10
# Source to node 911 : 9
# Source to node 912 : 10
# Source to node 913 : 10
# Source to node 914 : 9
# Source to node 915 : 10
# Source to node 916 : 10
# Source to node 917 : 10
# Source to node 918 : 10
# Source to node 919 : 10
# Source to node 920 : 10
# Source to node 921 : 10
# Source to node 922 : 10
# Source to node 923 : 10
# Source to node 924 : 10
# Source to node 925 : 10
# Source to node 926 : 9
# Source to node 927 : 10
# Source to node 928 : 10
# Source to node 929 : 10
# Source to node 930 : 10
# Source to node 931 : 10
# Source to node 932 : 10
# Source to node 933 : 10
# Source to node 934 : 10
# Source to node 935 : 10
# Source to node 936 : 9
# Source to node 937 : 10
# Source to node 938 : 10
# Source to node 939 : 10
# Source to node 940 : 10
# Source to node 941 : 10
# Source to node 942 : 10
# Source to node 943 : 10
# Source to node 944 : 10
# Source to node 945 : 10
# Source to node 946 : 10
# Source to node 947 : 10
# Source to node 948 : 10
# Source to node 949 : 10
# Source to node 950 : 10
# Source to node 951 : 10
# Source to node 952 : 10
# Source to node 953 : 10
# Source to node 954 : 10
# Source to node 955 : 10
# Source to node 956 : 10
# Source to node 957 : 10
# Source to node 958 : 10
# Source to node 959 : 10
# Source to node 960 : 9
# Source to node 961 : 10
# Source to node 962 : 10
# Source to node 963 : 9
# Source to node 964 : 10
# Source to node 965 : 10
# Source to node 966 : 10
# Source to node 967 : 10
# Source to node 968 : 10
# Source to node 969 : 10
# Source to node 970 : 10
# Source to node 971 : 10
# Source to node 972 : 10
# Source to node 973 : 10
# Source to node 974 : 9
# Source to node 975 : 10
# Source to node 976 : 10
# Source to node 977 : 10
# Source to node 978 : 10
# Source to node 979 : 10
# Source to node 980 : 10
# Source to node 981 : 10
# Source to node 982 : 10
# Source to node 983 : 10
# Source to node 984 : 10
# Source to node 985 : 10
# Source to node 986 : 9
# Source to node 987 : 10
# Source to node 988 : 10
# Source to node 989 : 10
# Source to node 990 : 10
# Source to node 991 : 10
# Source to node 992 : 10
# Source to node 993 : 10
# Source to node 994 : 10
# Source to node 995 : 10
# Source to node 996 : 10
# Source to node 997 : 10
# Source to node 998 : 10
# Source to node 999 : 9
#
# Path to get to each node,
# Path from source to node 0
# []
#
# Path from source to node 1
# [0]
#
# Path from source to node 2
# [0, 1, 11]
#
# Path from source to node 3
# [0, 1, 11, 85]
#
# Path from source to node 4
# [0, 1]
#
# Path from source to node 5
# [0, 1, 11, 63]
#
# Path from source to node 6
# [0, 1, 11, 347]
#
# Path from source to node 7
# [0, 1, 11]
#
# Path from source to node 8
# [0, 1, 11, 30, 47, 48, 87]
#
# Path from source to node 9
# [0, 1, 47, 87]
#
# Path from source to node 10
# [0, 1]
#
# Path from source to node 11
# [0, 1]
#
# Path from source to node 12
# [0, 1]
#
# Path from source to node 13
# [0, 1, 11, 44]
#
# Path from source to node 14
# [0, 1, 11, 44, 68]
#
# Path from source to node 15
# [0, 1, 30]
#
# Path from source to node 16
# [0, 1, 11, 30, 48, 68, 89]
#
# Path from source to node 17
# [0, 1, 30]
#
# Path from source to node 18
# [0, 1, 11, 158]
#
# Path from source to node 19
# [0, 1, 48]
#
# Path from source to node 20
# [0, 1, 11]
#
# Path from source to node 21
# [0, 1, 11, 63]
#
# Path from source to node 22
# [0, 1, 101, 122, 136]
#
# Path from source to node 23
# [0, 1, 11]
#
# Path from source to node 24
# [0, 1, 30, 68]
#
# Path from source to node 25
# [0, 1, 44]
#
# Path from source to node 26
# [0, 1, 30, 158]
#
# Path from source to node 27
# [0, 1, 11, 47]
#
# Path from source to node 28
# [0, 1, 30, 68, 89]
#
# Path from source to node 29
# [0, 1, 44]
#
# Path from source to node 30
# [0, 1]
#
# Path from source to node 31
# [0, 1, 11]
#
# Path from source to node 32
# [0, 1, 47]
#
# Path from source to node 33
# [0, 1]
#
# Path from source to node 34
# [0, 1]
#
# Path from source to node 35
# [0, 1, 47, 125]
#
# Path from source to node 36
# [0, 1, 63, 72]
#
# Path from source to node 37
# [0, 1]
#
# Path from source to node 38
# [0, 1, 11, 48]
#
# Path from source to node 39
# [0, 1, 122]
#
# Path from source to node 40
# [0, 1, 11, 68, 136]
#
# Path from source to node 41
# [0, 1, 11]
#
# Path from source to node 42
# [0, 1, 68]
#
# Path from source to node 43
# [0, 1, 11, 30]
#
# Path from source to node 44
# [0, 1]
#
# Path from source to node 45
# [0, 1, 11, 147]
#
# Path from source to node 46
# [0, 1, 11, 87]
#
# Path from source to node 47
# [0, 1]
#
# Path from source to node 48
# [0, 1]
#
# Path from source to node 49
# [0, 1, 11, 30, 47]
#
# Path from source to node 50
# [0, 1]
#
# Path from source to node 51
# [0, 1, 341]
#
# Path from source to node 52
# [0, 1, 11]
#
# Path from source to node 53
# [0, 1, 11, 30, 70]
#
# Path from source to node 54
# [0, 1, 30, 89, 90]
#
# Path from source to node 55
# [0, 1, 68]
#
# Path from source to node 56
# [0, 1, 11]
#
# Path from source to node 57
# [0, 1, 30, 134]
#
# Path from source to node 58
# [0, 1]
#
# Path from source to node 59
# [0, 1, 11, 30]
#
# Path from source to node 60
# [0, 1, 68]
#
# Path from source to node 61
# [0, 1, 11, 47, 63]
#
# Path from source to node 62
# [0, 1]
#
# Path from source to node 63
# [0, 1]
#
# Path from source to node 64
# [0, 1, 47, 70, 192]
#
# Path from source to node 65
# [0, 1, 163]
#
# Path from source to node 66
# [0, 1]
#
# Path from source to node 67
# [0, 1, 30, 44, 90]
#
# Path from source to node 68
# [0, 1]
#
# Path from source to node 69
# [0, 1, 11, 48, 158]
#
# Path from source to node 70
# [0, 1]
#
# Path from source to node 71
# [0, 1, 47]
#
# Path from source to node 72
# [0, 1]
#
# Path from source to node 73
# [0, 1, 48, 87]
#
# Path from source to node 74
# [0, 1, 44]
#
# Path from source to node 75
# [0, 1, 30, 44]
#
# Path from source to node 76
# [0, 1, 30]
#
# Path from source to node 77
# [0, 1, 11]
#
# Path from source to node 78
# [0, 1, 11]
#
# Path from source to node 79
# [0, 1, 89]
#
# Path from source to node 80
# [0, 1, 11]
#
# Path from source to node 81
# [0, 1, 11, 72]
#
# Path from source to node 82
# [0, 1, 112]
#
# Path from source to node 83
# [0, 1, 47, 48]
#
# Path from source to node 84
# [0, 1, 30, 44, 48, 122, 211]
#
# Path from source to node 85
# [0, 1]
#
# Path from source to node 86
# [0, 1, 30]
#
# Path from source to node 87
# [0, 1]
#
# Path from source to node 88
# [0, 1]
#
# Path from source to node 89
# [0, 1]
#
# Path from source to node 90
# [0, 1]
#
# Path from source to node 91
# [0, 1, 11, 30, 47]
#
# Path from source to node 92
# [0, 1, 30, 87, 136]
#
# Path from source to node 93
# [0, 1, 47, 68, 117]
#
# Path from source to node 94
# [0, 1, 11, 30, 48]
#
# Path from source to node 95
# [0, 1, 11, 30, 44, 90]
#
# Path from source to node 96
# [0, 1, 11]
#
# Path from source to node 97
# [0, 1, 11]
#
# Path from source to node 98
# [0, 1, 103]
#
# Path from source to node 99
# [0, 1, 30, 47]
#
# Path from source to node 100
# [0, 1, 68, 90]
#
# Path from source to node 101
# [0, 1]
#
# Path from source to node 102
# [0, 1, 87]
#
# Path from source to node 103
# [0, 1]
#
# Path from source to node 104
# [0, 1, 47, 48]
#
# Path from source to node 105
# [0, 1]
#
# Path from source to node 106
# [0, 1, 68, 72]
#
# Path from source to node 107
# [0, 1, 11, 30]
#
# Path from source to node 108
# [0, 1, 30, 47]
#
# Path from source to node 109
# [0, 1]
#
# Path from source to node 110
# [0, 1, 63]
#
# Path from source to node 111
# [0, 1, 30, 125]
#
# Path from source to node 112
# [0, 1]
#
# Path from source to node 113
# [0, 1, 30, 87]
#
# Path from source to node 114
# [0, 1, 11]
#
# Path from source to node 115
# [0, 1, 11, 89]
#
# Path from source to node 116
# [0, 1, 11, 48]
#
# Path from source to node 117
# [0, 1]
#
# Path from source to node 118
# [0, 1]
#
# Path from source to node 119
# [0, 1, 11, 90, 130]
#
# Path from source to node 120
# [0, 1, 44]
#
# Path from source to node 121
# [0, 1]
#
# Path from source to node 122
# [0, 1]
#
# Path from source to node 123
# [0, 1, 63, 68]
#
# Path from source to node 124
# [0, 1]
#
# Path from source to node 125
# [0, 1]
#
# Path from source to node 126
# [0, 1, 48]
#
# Path from source to node 127
# [0, 1, 63, 87]
#
# Path from source to node 128
# [0, 1, 11, 30, 48, 63]
#
# Path from source to node 129
# [0, 1]
#
# Path from source to node 130
# [0, 1]
#
# Path from source to node 131
# [0, 1, 11, 103]
#
# Path from source to node 132
# [0, 1]
#
# Path from source to node 133
# [0, 1, 47, 68, 85, 89]
#
# Path from source to node 134
# [0, 1]
#
# Path from source to node 135
# [0, 1, 30, 89, 158]
#
# Path from source to node 136
# [0, 1]
#
# Path from source to node 137
# [0, 1, 11, 30]
#
# Path from source to node 138
# [0, 1, 47]
#
# Path from source to node 139
# [0, 1, 11, 85]
#
# Path from source to node 140
# [0, 1, 11, 30, 47]
#
# Path from source to node 141
# [0, 1, 11, 44, 63, 103]
#
# Path from source to node 142
# [0, 1, 11]
#
# Path from source to node 143
# [0, 1, 11]
#
# Path from source to node 144
# [0, 1, 30, 47, 70]
#
# Path from source to node 145
# [0, 1]
#
# Path from source to node 146
# [0, 1, 11, 44, 87, 121]
#
# Path from source to node 147
# [0, 1]
#
# Path from source to node 148
# [0, 1, 87]
#
# Path from source to node 149
# [0, 1, 11]
#
# Path from source to node 150
# [0, 1, 30, 44, 63]
#
# Path from source to node 151
# [0, 1, 11]
#
# Path from source to node 152
# [0, 1, 11, 44, 68]
#
# Path from source to node 153
# [0, 1]
#
# Path from source to node 154
# [0, 1, 11, 68]
#
# Path from source to node 155
# [0, 1]
#
# Path from source to node 156
# [0, 1, 30, 44, 48, 70]
#
# Path from source to node 157
# [0, 1, 30, 44, 47, 425]
#
# Path from source to node 158
# [0, 1]
#
# Path from source to node 159
# [0, 1, 11, 30, 44]
#
# Path from source to node 160
# [0, 1, 30, 87]
#
# Path from source to node 161
# [0, 1, 11, 72]
#
# Path from source to node 162
# [0, 1, 11]
#
# Path from source to node 163
# [0, 1]
#
# Path from source to node 164
# [0, 1, 11, 30, 63, 68]
#
# Path from source to node 165
# [0, 1, 44, 63, 90]
#
# Path from source to node 166
# [0, 1, 30, 63]
#
# Path from source to node 167
# [0, 1, 11, 68]
#
# Path from source to node 168
# [0, 1, 11, 44]
#
# Path from source to node 169
# [0, 1, 11]
#
# Path from source to node 170
# [0, 1]
#
# Path from source to node 171
# [0, 1, 48, 101, 117]
#
# Path from source to node 172
# [0, 1, 48, 130]
#
# Path from source to node 173
# [0, 1, 11, 30, 89]
#
# Path from source to node 174
# [0, 1, 30, 44]
#
# Path from source to node 175
# [0, 1, 44]
#
# Path from source to node 176
# [0, 1, 11]
#
# Path from source to node 177
# [0, 1, 44, 85, 90]
#
# Path from source to node 178
# [0, 1, 11, 30, 48]
#
# Path from source to node 179
# [0, 1, 47]
#
# Path from source to node 180
# [0, 1, 11, 48, 72]
#
# Path from source to node 181
# [0, 1, 134]
#
# Path from source to node 182
# [0, 1, 11, 30]
#
# Path from source to node 183
# [0, 1, 11, 44, 101, 117, 239]
#
# Path from source to node 184
# [0, 1]
#
# Path from source to node 185
# [0, 1, 30, 44, 70]
#
# Path from source to node 186
# [0, 1]
#
# Path from source to node 187
# [0, 1, 47, 68, 122]
#
# Path from source to node 188
# [0, 1, 11, 70, 85]
#
# Path from source to node 189
# [0, 1]
#
# Path from source to node 190
# [0, 1, 11]
#
# Path from source to node 191
# [0, 1, 70]
#
# Path from source to node 192
# [0, 1]
#
# Path from source to node 193
# [0, 1, 117]
#
# Path from source to node 194
# [0, 1]
#
# Path from source to node 195
# [0, 1, 11, 47]
#
# Path from source to node 196
# [0, 1]
#
# Path from source to node 197
# [0, 1]
#
# Path from source to node 198
# [0, 1, 44, 89]
#
# Path from source to node 199
# [0, 1, 11, 30, 44, 47, 89]
#
# Path from source to node 200
# [0, 1, 11]
#
# Path from source to node 201
# [0, 1]
#
# Path from source to node 202
# [0, 1, 11]
#
# Path from source to node 203
# [0, 1, 47, 48]
#
# Path from source to node 204
# [0, 1, 11, 30, 44, 85]
#
# Path from source to node 205
# [0, 1]
#
# Path from source to node 206
# [0, 1, 11, 44, 89]
#
# Path from source to node 207
# [0, 1, 30, 47]
#
# Path from source to node 208
# [0, 1, 11, 70, 85, 101]
#
# Path from source to node 209
# [0, 1, 11]
#
# Path from source to node 210
# [0, 1, 30, 48]
#
# Path from source to node 211
# [0, 1]
#
# Path from source to node 212
# [0, 1, 44, 63]
#
# Path from source to node 213
# [0, 1, 11, 30]
#
# Path from source to node 214
# [0, 1, 44, 63, 101]
#
# Path from source to node 215
# [0, 1, 11, 68, 158]
#
# Path from source to node 216
# [0, 1, 11, 30]
#
# Path from source to node 217
# [0, 1, 11, 30, 63]
#
# Path from source to node 218
# [0, 1, 11, 85]
#
# Path from source to node 219
# [0, 1, 11, 136]
#
# Path from source to node 220
# [0, 1, 11, 103]
#
# Path from source to node 221
# [0, 1, 11, 87]
#
# Path from source to node 222
# [0, 1, 44, 136]
#
# Path from source to node 223
# [0, 1, 72]
#
# Path from source to node 224
# [0, 1, 134]
#
# Path from source to node 225
# [0, 1, 44, 68]
#
# Path from source to node 226
# [0, 1, 63]
#
# Path from source to node 227
# [0, 1, 11, 30, 47, 397]
#
# Path from source to node 228
# [0, 1, 44, 85, 87]
#
# Path from source to node 229
# [0, 1, 11, 30]
#
# Path from source to node 230
# [0, 1]
#
# Path from source to node 231
# [0, 1, 11, 30]
#
# Path from source to node 232
# [0, 1, 30, 117, 130]
#
# Path from source to node 233
# [0, 1, 30, 47]
#
# Path from source to node 234
# [0, 1, 11, 44]
#
# Path from source to node 235
# [0, 1, 44, 85]
#
# Path from source to node 236
# [0, 1, 30, 72, 479]
#
# Path from source to node 237
# [0, 1, 11, 44]
#
# Path from source to node 238
# [0, 1, 30, 68, 70]
#
# Path from source to node 239
# [0, 1]
#
# Path from source to node 240
# [0, 1, 11]
#
# Path from source to node 241
# [0, 1, 30, 47, 68]
#
# Path from source to node 242
# [0, 1, 30, 44]
#
# Path from source to node 243
# [0, 1, 11, 44, 47]
#
# Path from source to node 244
# [0, 1, 11, 47]
#
# Path from source to node 245
# [0, 1]
#
# Path from source to node 246
# [0, 1]
#
# Path from source to node 247
# [0, 1, 70, 103]
#
# Path from source to node 248
# [0, 1, 11]
#
# Path from source to node 249
# [0, 1, 44, 316]
#
# Path from source to node 250
# [0, 1]
#
# Path from source to node 251
# [0, 1]
#
# Path from source to node 252
# [0, 1, 11, 70]
#
# Path from source to node 253
# [0, 1, 11, 30]
#
# Path from source to node 254
# [0, 1, 30, 44]
#
# Path from source to node 255
# [0, 1, 11, 48, 63, 85]
#
# Path from source to node 256
# [0, 1, 70, 72]
#
# Path from source to node 257
# [0, 1, 44]
#
# Path from source to node 258
# [0, 1, 11, 30, 72]
#
# Path from source to node 259
# [0, 1, 48, 194]
#
# Path from source to node 260
# [0, 1, 44, 48]
#
# Path from source to node 261
# [0, 1, 11, 89, 125]
#
# Path from source to node 262
# [0, 1, 11, 44]
#
# Path from source to node 263
# [0, 1, 11, 30]
#
# Path from source to node 264
# [0, 1, 11, 89]
#
# Path from source to node 265
# [0, 1, 11, 70]
#
# Path from source to node 266
# [0, 1, 63]
#
# Path from source to node 267
# [0, 1, 11, 63]
#
# Path from source to node 268
# [0, 1, 11, 101, 136]
#
# Path from source to node 269
# [0, 1, 47]
#
# Path from source to node 270
# [0, 1]
#
# Path from source to node 271
# [0, 1, 11, 68]
#
# Path from source to node 272
# [0, 1]
#
# Path from source to node 273
# [0, 1, 11, 30, 63, 68, 72]
#
# Path from source to node 274
# [0, 1, 44]
#
# Path from source to node 275
# [0, 1, 44, 48]
#
# Path from source to node 276
# [0, 1]
#
# Path from source to node 277
# [0, 1, 47, 122]
#
# Path from source to node 278
# [0, 1, 11, 48, 72, 89]
#
# Path from source to node 279
# [0, 1, 89]
#
# Path from source to node 280
# [0, 1, 11, 44, 89]
#
# Path from source to node 281
# [0, 1, 11]
#
# Path from source to node 282
# [0, 1, 63, 134]
#
# Path from source to node 283
# [0, 1, 44, 48]
#
# Path from source to node 284
# [0, 1, 11]
#
# Path from source to node 285
# [0, 1, 11, 72]
#
# Path from source to node 286
# [0, 1, 72, 122]
#
# Path from source to node 287
# [0, 1, 44, 63, 68, 121]
#
# Path from source to node 288
# [0, 1, 11]
#
# Path from source to node 289
# [0, 1, 11]
#
# Path from source to node 290
# [0, 1, 11, 70]
#
# Path from source to node 291
# [0, 1]
#
# Path from source to node 292
# [0, 1]
#
# Path from source to node 293
# [0, 1, 11, 30, 44]
#
# Path from source to node 294
# [0, 1, 11, 122]
#
# Path from source to node 295
# [0, 1, 30, 48]
#
# Path from source to node 296
# [0, 1, 11, 85, 90]
#
# Path from source to node 297
# [0, 1, 11, 63, 101, 112]
#
# Path from source to node 298
# [0, 1, 30]
#
# Path from source to node 299
# [0, 1, 11]
#
# Path from source to node 300
# [0, 1, 63]
#
# Path from source to node 301
# [0, 1, 44]
#
# Path from source to node 302
# [0, 1]
#
# Path from source to node 303
# [0, 1, 11, 87]
#
# Path from source to node 304
# [0, 1, 30]
#
# Path from source to node 305
# [0, 1]
#
# Path from source to node 306
# [0, 1, 72]
#
# Path from source to node 307
# [0, 1]
#
# Path from source to node 308
# [0, 1, 63]
#
# Path from source to node 309
# [0, 1, 30, 48, 68]
#
# Path from source to node 310
# [0, 1, 30, 72, 121]
#
# Path from source to node 311
# [0, 1, 11, 30, 48]
#
# Path from source to node 312
# [0, 1, 44, 47, 48]
#
# Path from source to node 313
# [0, 1, 11]
#
# Path from source to node 314
# [0, 1, 63, 121]
#
# Path from source to node 315
# [0, 1]
#
# Path from source to node 316
# [0, 1]
#
# Path from source to node 317
# [0, 1, 70]
#
# Path from source to node 318
# [0, 1, 11, 63]
#
# Path from source to node 319
# [0, 1, 11, 68, 121, 130]
#
# Path from source to node 320
# [0, 1, 48]
#
# Path from source to node 321
# [0, 1, 47, 63]
#
# Path from source to node 322
# [0, 1]
#
# Path from source to node 323
# [0, 1, 11]
#
# Path from source to node 324
# [0, 1, 72]
#
# Path from source to node 325
# [0, 1, 11, 30, 89]
#
# Path from source to node 326
# [0, 1, 194]
#
# Path from source to node 327
# [0, 1, 502]
#
# Path from source to node 328
# [0, 1]
#
# Path from source to node 329
# [0, 1, 11]
#
# Path from source to node 330
# [0, 1, 44]
#
# Path from source to node 331
# [0, 1, 30]
#
# Path from source to node 332
# [0, 1]
#
# Path from source to node 333
# [0, 1, 30, 211]
#
# Path from source to node 334
# [0, 1, 30]
#
# Path from source to node 335
# [0, 1, 11, 63]
#
# Path from source to node 336
# [0, 1]
#
# Path from source to node 337
# [0, 1, 30, 72]
#
# Path from source to node 338
# [0, 1, 89]
#
# Path from source to node 339
# [0, 1, 11]
#
# Path from source to node 340
# [0, 1, 11, 63, 85]
#
# Path from source to node 341
# [0, 1]
#
# Path from source to node 342
# [0, 1, 11, 89]
#
# Path from source to node 343
# [0, 1, 30, 89, 134]
#
# Path from source to node 344
# [0, 1, 44, 47, 48]
#
# Path from source to node 345
# [0, 1]
#
# Path from source to node 346
# [0, 1]
#
# Path from source to node 347
# [0, 1]
#
# Path from source to node 348
# [0, 1, 11, 72]
#
# Path from source to node 349
# [0, 1, 11]
#
# Path from source to node 350
# [0, 1, 11]
#
# Path from source to node 351
# [0, 1, 194]
#
# Path from source to node 352
# [0, 1, 30, 48]
#
# Path from source to node 353
# [0, 1, 11]
#
# Path from source to node 354
# [0, 1, 30]
#
# Path from source to node 355
# [0, 1]
#
# Path from source to node 356
# [0, 1, 87, 117]
#
# Path from source to node 357
# [0, 1, 44, 305]
#
# Path from source to node 358
# [0, 1, 48, 121]
#
# Path from source to node 359
# [0, 1, 11, 30, 47]
#
# Path from source to node 360
# [0, 1, 44]
#
# Path from source to node 361
# [0, 1, 87]
#
# Path from source to node 362
# [0, 1, 11, 30, 44, 63]
#
# Path from source to node 363
# [0, 1, 44, 70, 250]
#
# Path from source to node 364
# [0, 1, 136]
#
# Path from source to node 365
# [0, 1, 47, 117, 125]
#
# Path from source to node 366
# [0, 1, 30, 47, 103]
#
# Path from source to node 367
# [0, 1, 47, 63, 68]
#
# Path from source to node 368
# [0, 1, 11, 30, 68, 412]
#
# Path from source to node 369
# [0, 1, 63, 101, 211]
#
# Path from source to node 370
# [0, 1, 11, 89]
#
# Path from source to node 371
# [0, 1, 68]
#
# Path from source to node 372
# [0, 1, 11, 68]
#
# Path from source to node 373
# [0, 1, 30, 44, 158]
#
# Path from source to node 374
# [0, 1, 47]
#
# Path from source to node 375
# [0, 1, 30, 130, 136]
#
# Path from source to node 376
# [0, 1, 30, 47, 48]
#
# Path from source to node 377
# [0, 1]
#
# Path from source to node 378
# [0, 1]
#
# Path from source to node 379
# [0, 1, 11]
#
# Path from source to node 380
# [0, 1]
#
# Path from source to node 381
# [0, 1, 11, 44, 48]
#
# Path from source to node 382
# [0, 1, 11, 70]
#
# Path from source to node 383
# [0, 1, 11, 122]
#
# Path from source to node 384
# [0, 1, 11, 44]
#
# Path from source to node 385
# [0, 1, 30, 87, 130]
#
# Path from source to node 386
# [0, 1, 30, 85, 125]
#
# Path from source to node 387
# [0, 1, 47, 85, 425]
#
# Path from source to node 388
# [0, 1]
#
# Path from source to node 389
# [0, 1, 11, 44, 72, 101]
#
# Path from source to node 390
# [0, 1, 121]
#
# Path from source to node 391
# [0, 1, 11, 70]
#
# Path from source to node 392
# [0, 1, 11, 87]
#
# Path from source to node 393
# [0, 1, 44, 47]
#
# Path from source to node 394
# [0, 1, 11, 72]
#
# Path from source to node 395
# [0, 1, 63]
#
# Path from source to node 396
# [0, 1, 11]
#
# Path from source to node 397
# [0, 1]
#
# Path from source to node 398
# [0, 1, 11]
#
# Path from source to node 399
# [0, 1, 11, 44, 70]
#
# Path from source to node 400
# [0, 1, 30, 48, 89]
#
# Path from source to node 401
# [0, 1, 11, 44, 194]
#
# Path from source to node 402
# [0, 1, 30, 103]
#
# Path from source to node 403
# [0, 1, 44, 239]
#
# Path from source to node 404
# [0, 1, 44]
#
# Path from source to node 405
# [0, 1, 11, 112]
#
# Path from source to node 406
# [0, 1, 30, 44, 48]
#
# Path from source to node 407
# [0, 1, 87]
#
# Path from source to node 408
# [0, 1]
#
# Path from source to node 409
# [0, 1]
#
# Path from source to node 410
# [0, 1]
#
# Path from source to node 411
# [0, 1, 30, 44, 112]
#
# Path from source to node 412
# [0, 1]
#
# Path from source to node 413
# [0, 1, 30, 68]
#
# Path from source to node 414
# [0, 1, 11, 48, 68]
#
# Path from source to node 415
# [0, 1, 11, 89]
#
# Path from source to node 416
# [0, 1, 11, 30, 44]
#
# Path from source to node 417
# [0, 1, 11, 47, 68]
#
# Path from source to node 418
# [0, 1, 101]
#
# Path from source to node 419
# [0, 1, 11]
#
# Path from source to node 420
# [0, 1]
#
# Path from source to node 421
# [0, 1]
#
# Path from source to node 422
# [0, 1, 63]
#
# Path from source to node 423
# [0, 1, 30, 147]
#
# Path from source to node 424
# [0, 1, 30, 44]
#
# Path from source to node 425
# [0, 1]
#
# Path from source to node 426
# [0, 1, 11, 72]
#
# Path from source to node 427
# [0, 1, 30, 44, 103]
#
# Path from source to node 428
# [0, 1, 11, 47, 112]
#
# Path from source to node 429
# [0, 1]
#
# Path from source to node 430
# [0, 1, 11, 44]
#
# Path from source to node 431
# [0, 1, 44]
#
# Path from source to node 432
# [0, 1, 11, 85, 305]
#
# Path from source to node 433
# [0, 1, 44, 48, 85]
#
# Path from source to node 434
# [0, 1, 47]
#
# Path from source to node 435
# [0, 1, 30, 47]
#
# Path from source to node 436
# [0, 1]
#
# Path from source to node 437
# [0, 1, 239]
#
# Path from source to node 438
# [0, 1, 30]
#
# Path from source to node 439
# [0, 1, 11, 44]
#
# Path from source to node 440
# [0, 1, 11, 125]
#
# Path from source to node 441
# [0, 1, 44, 136, 192]
#
# Path from source to node 442
# [0, 1, 30, 47, 89]
#
# Path from source to node 443
# [0, 1]
#
# Path from source to node 444
# [0, 1, 11, 47, 87]
#
# Path from source to node 445
# [0, 1, 11]
#
# Path from source to node 446
# [0, 1, 11]
#
# Path from source to node 447
# [0, 1]
#
# Path from source to node 448
# [0, 1, 44, 47, 48]
#
# Path from source to node 449
# [0, 1, 11, 68]
#
# Path from source to node 450
# [0, 1, 44, 47]
#
# Path from source to node 451
# [0, 1, 11, 30]
#
# Path from source to node 452
# [0, 1, 11, 101]
#
# Path from source to node 453
# [0, 1, 30, 48, 85]
#
# Path from source to node 454
# [0, 1, 44]
#
# Path from source to node 455
# [0, 1, 11]
#
# Path from source to node 456
# [0, 1, 11, 72]
#
# Path from source to node 457
# [0, 1, 44, 63]
#
# Path from source to node 458
# [0, 1, 48, 63]
#
# Path from source to node 459
# [0, 1, 11]
#
# Path from source to node 460
# [0, 1, 11, 63]
#
# Path from source to node 461
# [0, 1, 122]
#
# Path from source to node 462
# [0, 1, 85, 103]
#
# Path from source to node 463
# [0, 1, 11, 63]
#
# Path from source to node 464
# [0, 1, 30, 44, 125]
#
# Path from source to node 465
# [0, 1]
#
# Path from source to node 466
# [0, 1]
#
# Path from source to node 467
# [0, 1]
#
# Path from source to node 468
# [0, 1, 11, 48]
#
# Path from source to node 469
# [0, 1, 11]
#
# Path from source to node 470
# [0, 1, 11, 30, 63, 68]
#
# Path from source to node 471
# [0, 1, 11, 44, 90]
#
# Path from source to node 472
# [0, 1, 70]
#
# Path from source to node 473
# [0, 1, 44]
#
# Path from source to node 474
# [0, 1, 30, 85]
#
# Path from source to node 475
# [0, 1, 30, 48, 122]
#
# Path from source to node 476
# [0, 1, 11, 30, 47, 136]
#
# Path from source to node 477
# [0, 1, 11, 44, 85]
#
# Path from source to node 478
# [0, 1, 11, 68]
#
# Path from source to node 479
# [0, 1]
#
# Path from source to node 480
# [0, 1, 11, 44, 47, 48]
#
# Path from source to node 481
# [0, 1, 63]
#
# Path from source to node 482
# [0, 1, 11]
#
# Path from source to node 483
# [0, 1, 11, 30]
#
# Path from source to node 484
# [0, 1]
#
# Path from source to node 485
# [0, 1, 11, 63, 117, 136]
#
# Path from source to node 486
# [0, 1, 130]
#
# Path from source to node 487
# [0, 1, 11, 30, 44]
#
# Path from source to node 488
# [0, 1, 44, 47]
#
# Path from source to node 489
# [0, 1, 30, 48, 72, 112]
#
# Path from source to node 490
# [0, 1]
#
# Path from source to node 491
# [0, 1, 11, 30]
#
# Path from source to node 492
# [0, 1, 47]
#
# Path from source to node 493
# [0, 1]
#
# Path from source to node 494
# [0, 1, 44, 47]
#
# Path from source to node 495
# [0, 1, 11, 44, 68, 70, 103]
#
# Path from source to node 496
# [0, 1, 11, 72]
#
# Path from source to node 497
# [0, 1, 11, 30, 44, 68]
#
# Path from source to node 498
# [0, 1, 30, 47]
#
# Path from source to node 499
# [0, 1]
#
# Path from source to node 500
# [0, 1]
#
# Path from source to node 501
# [0, 1]
#
# Path from source to node 502
# [0, 1]
#
# Path from source to node 503
# [0, 1, 11]
#
# Path from source to node 504
# [0, 1, 11, 112]
#
# Path from source to node 505
# [0, 1]
#
# Path from source to node 506
# [0, 1]
#
# Path from source to node 507
# [0, 1, 11, 47]
#
# Path from source to node 508
# [0, 1]
#
# Path from source to node 509
# [0, 1, 11, 30]
#
# Path from source to node 510
# [0, 1]
#
# Path from source to node 511
# [0, 1, 11]
#
# Path from source to node 512
# [0, 1, 11]
#
# Path from source to node 513
# [0, 1]
#
# Path from source to node 514
# [0, 1, 68, 117]
#
# Path from source to node 515
# [0, 1, 11, 30, 44, 48]
#
# Path from source to node 516
# [0, 1, 11, 48, 134]
#
# Path from source to node 517
# [0, 1, 11, 47]
#
# Path from source to node 518
# [0, 1, 11, 85]
#
# Path from source to node 519
# [0, 1, 11, 30, 63, 72, 87]
#
# Path from source to node 520
# [0, 1, 44]
#
# Path from source to node 521
# [0, 1, 44]
#
# Path from source to node 522
# [0, 1, 63, 68]
#
# Path from source to node 523
# [0, 1, 11, 47]
#
# Path from source to node 524
# [0, 1, 47]
#
# Path from source to node 525
# [0, 1, 47]
#
# Path from source to node 526
# [0, 1, 70, 89]
#
# Path from source to node 527
# [0, 1, 136]
#
# Path from source to node 528
# [0, 1]
#
# Path from source to node 529
# [0, 1, 30, 89]
#
# Path from source to node 530
# [0, 1, 11]
#
# Path from source to node 531
# [0, 1]
#
# Path from source to node 532
# [0, 1, 11]
#
# Path from source to node 533
# [0, 1]
#
# Path from source to node 534
# [0, 1, 85, 87, 122, 136]
#
# Path from source to node 535
# [0, 1, 11, 44, 48, 239]
#
# Path from source to node 536
# [0, 1, 48]
#
# Path from source to node 537
# [0, 1, 11, 48]
#
# Path from source to node 538
# [0, 1, 11]
#
# Path from source to node 539
# [0, 1, 44]
#
# Path from source to node 540
# [0, 1, 47]
#
# Path from source to node 541
# [0, 1, 30]
#
# Path from source to node 542
# [0, 1]
#
# Path from source to node 543
# [0, 1, 11, 44]
#
# Path from source to node 544
# [0, 1]
#
# Path from source to node 545
# [0, 1, 48, 90]
#
# Path from source to node 546
# [0, 1, 11, 47, 48, 87, 136]
#
# Path from source to node 547
# [0, 1]
#
# Path from source to node 548
# [0, 1, 30]
#
# Path from source to node 549
# [0, 1, 30, 112]
#
# Path from source to node 550
# [0, 1, 11, 30, 500]
#
# Path from source to node 551
# [0, 1, 30, 68, 90]
#
# Path from source to node 552
# [0, 1, 11, 47]
#
# Path from source to node 553
# [0, 1, 44, 48, 63]
#
# ...
# [0, 1]
#
# Path from source to node 634
# [0, 1, 11, 44]
#
# Path from source to node 635
# [0, 1, 11, 44, 48]
#
# Path from source to node 636
# [0, 1, 11, 72]
#
# Path from source to node 637
# [0, 1, 11, 30, 48, 68, 136]
#
# Path from source to node 638
# [0, 1, 44, 70]
#
# Path from source to node 639
# [0, 1, 11, 122]
#
# Path from source to node 640
# [0, 1, 30]
#
# Path from source to node 641
# [0, 1, 44]
#
# Path from source to node 642
# [0, 1, 11, 121]
#
# Path from source to node 643
# [0, 1]
#
# Path from source to node 644
# [0, 1, 44, 48]
#
# Path from source to node 645
# [0, 1, 11, 87]
#
# Path from source to node 646
# [0, 1, 11]
#
# Path from source to node 647
# [0, 1]
#
# Path from source to node 648
# [0, 1, 11, 44]
#
# Path from source to node 649
# [0, 1, 112]
#
# Path from source to node 650
# [0, 1, 11, 47, 63]
#
# Path from source to node 651
# [0, 1, 44, 72]
#
# Path from source to node 652
# [0, 1, 11, 47]
#
# Path from source to node 653
# [0, 1, 44, 72, 85]
#
# Path from source to node 654
# [0, 1, 30, 44]
#
# Path from source to node 655
# [0, 1, 48, 63, 125]
#
# Path from source to node 656
# [0, 1, 11, 134]
#
# Path from source to node 657
# [0, 1, 68, 70]
#
# Path from source to node 658
# [0, 1]
#
# Path from source to node 659
# [0, 1, 68, 117]
#
# Path from source to node 660
# [0, 1]
#
# Path from source to node 661
# [0, 1, 44, 47]
#
# Path from source to node 662
# [0, 1, 11, 30, 48]
#
# Path from source to node 663
# [0, 1, 48]
#
# Path from source to node 664
# [0, 1, 11, 44, 103]
#
# Path from source to node 665
# [0, 1, 11]
#
# Path from source to node 666
# [0, 1, 11, 44, 192]
#
# Path from source to node 667
# [0, 1]
#
# Path from source to node 668
# [0, 1, 11]
#
# Path from source to node 669
# [0, 1, 68, 89]
#
# Path from source to node 670
# [0, 1, 11]
#
# Path from source to node 671
# [0, 1, 11]
#
# Path from source to node 672
# [0, 1]
#
# Path from source to node 673
# [0, 1, 48, 68]
#
# Path from source to node 674
# [0, 1, 47, 48]
#
# Path from source to node 675
# [0, 1, 11]
#
# Path from source to node 676
# [0, 1, 85, 121]
#
# Path from source to node 677
# [0, 1, 11]
#
# Path from source to node 678
# [0, 1, 30]
#
# Path from source to node 679
# [0, 1]
#
# Path from source to node 680
# [0, 1, 63]
#
# Path from source to node 681
# [0, 1, 44, 87]
#
# Path from source to node 682
# [0, 1, 11, 87]
#
# Path from source to node 683
# [0, 1, 47]
#
# Path from source to node 684
# [0, 1, 30]
#
# Path from source to node 685
# [0, 1, 11, 85, 101]
#
# Path from source to node 686
# [0, 1, 11, 85, 103]
#
# Path from source to node 687
# [0, 1, 30, 44, 87]
#
# Path from source to node 688
# [0, 1]
#
# Path from source to node 689
# [0, 1]
#
# Path from source to node 690
# [0, 1, 44, 70]
#
# Path from source to node 691
# [0, 1]
#
# Path from source to node 692
# [0, 1, 47]
#
# Path from source to node 693
# [0, 1, 63]
#
# Path from source to node 694
# [0, 1, 30]
#
# Path from source to node 695
# [0, 1, 48]
#
# Path from source to node 696
# [0, 1, 11]
#
# Path from source to node 697
# [0, 1, 68, 87]
#
# Path from source to node 698
# [0, 1, 44, 103]
#
# Path from source to node 699
# [0, 1, 30]
#
# Path from source to node 700
# [0, 1, 11, 68, 101]
#
# Path from source to node 701
# [0, 1, 30]
#
# Path from source to node 702
# [0, 1, 11, 44, 47]
#
# Path from source to node 703
# [0, 1]
#
# Path from source to node 704
# [0, 1, 11, 30]
#
# Path from source to node 705
# [0, 1]
#
# Path from source to node 706
# [0, 1]
#
# Path from source to node 707
# [0, 1]
#
# Path from source to node 708
# [0, 1, 490]
#
# Path from source to node 709
# [0, 1, 47, 48]
#
# Path from source to node 710
# [0, 1]
#
# Path from source to node 711
# [0, 1, 11]
#
# Path from source to node 712
# [0, 1]
#
# Path from source to node 713
# [0, 1, 70]
#
# Path from source to node 714
# [0, 1, 11, 48]
#
# Path from source to node 715
# [0, 1, 30]
#
# Path from source to node 716
# [0, 1]
#
# Path from source to node 717
# [0, 1, 30, 72]
#
# Path from source to node 718
# [0, 1, 30, 70]
#
# Path from source to node 719
# [0, 1, 44, 68]
#
# Path from source to node 720
# [0, 1]
#
# Path from source to node 721
# [0, 1, 11, 30, 47, 48]
#
# Path from source to node 722
# [0, 1]
#
# Path from source to node 723
# [0, 1, 11, 44]
#
# Path from source to node 724
# [0, 1, 30]
#
# Path from source to node 725
# [0, 1, 11]
#
# Path from source to node 726
# [0, 1]
#
# Path from source to node 727
# [0, 1]
#
# Path from source to node 728
# [0, 1, 11, 30, 44, 90]
#
# Path from source to node 729
# [0, 1, 11]
#
# Path from source to node 730
# [0, 1, 11, 30]
#
# Path from source to node 731
# [0, 1, 11, 63, 87]
#
# Path from source to node 732
# [0, 1, 30, 72]
#
# Path from source to node 733
# [0, 1, 47, 63, 101]
#
# Path from source to node 734
# [0, 1]
#
# Path from source to node 735
# [0, 1, 44, 89]
#
# Path from source to node 736
# [0, 1]
#
# Path from source to node 737
# [0, 1, 68]
#
# Path from source to node 738
# [0, 1]
#
# Path from source to node 739
# [0, 1]
#
# Path from source to node 740
# [0, 1]
#
# Path from source to node 741
# [0, 1]
#
# Path from source to node 742
# [0, 1, 11, 48]
#
# Path from source to node 743
# [0, 1, 11, 63]
#
# Path from source to node 744
# [0, 1, 30, 47, 48, 70, 136]
#
# Path from source to node 745
# [0, 1, 11, 63]
#
# Path from source to node 746
# [0, 1, 63]
#
# Path from source to node 747
# [0, 1]
#
# Path from source to node 748
# [0, 1, 11]
#
# Path from source to node 749
# [0, 1, 11, 85]
#
# Path from source to node 750
# [0, 1, 44, 103]
#
# Path from source to node 751
# [0, 1, 30, 63, 85]
#
# Path from source to node 752
# [0, 1, 11, 30]
#
# Path from source to node 753
# [0, 1, 30, 63, 89]
#
# Path from source to node 754
# [0, 1, 11, 70]
#
# Path from source to node 755
# [0, 1]
#
# Path from source to node 756
# [0, 1]
#
# Path from source to node 757
# [0, 1, 30, 44, 72]
#
# Path from source to node 758
# [0, 1, 11, 48]
#
# Path from source to node 759
# [0, 1, 63, 90]
#
# Path from source to node 760
# [0, 1, 30, 44, 47]
#
# Path from source to node 761
# [0, 1, 11, 70, 90]
#
# Path from source to node 762
# [0, 1, 11]
#
# Path from source to node 763
# [0, 1, 30, 48]
#
# Path from source to node 764
# [0, 1]
#
# Path from source to node 765
# [0, 1, 11, 44, 63, 70]
#
# Path from source to node 766
# [0, 1, 44, 70]
#
# Path from source to node 767
# [0, 1]
#
# Path from source to node 768
# [0, 1, 44, 47]
#
# Path from source to node 769
# [0, 1]
#
# Path from source to node 770
# [0, 1, 11, 70]
#
# Path from source to node 771
# [0, 1]
#
# Path from source to node 772
# [0, 1, 30]
#
# Path from source to node 773
# [0, 1, 11, 30, 101]
#
# Path from source to node 774
# [0, 1, 11, 30, 134]
#
# Path from source to node 775
# [0, 1]
#
# Path from source to node 776
# [0, 1]
#
# Path from source to node 777
# [0, 1, 11, 30, 44]
#
# Path from source to node 778
# [0, 1, 11, 30, 44]
#
# Path from source to node 779
# [0, 1, 11, 30, 89, 90]
#
# Path from source to node 780
# [0, 1, 30]
#
# Path from source to node 781
# [0, 1, 30, 44, 85, 239]
#
# Path from source to node 782
# [0, 1]
#
# Path from source to node 783
# [0, 1, 44, 87]
#
# Path from source to node 784
# [0, 1, 101]
#
# Path from source to node 785
# [0, 1]
#
# Path from source to node 786
# [0, 1, 30]
#
# Path from source to node 787
# [0, 1, 85]
#
# Path from source to node 788
# [0, 1, 44]
#
# Path from source to node 789
# [0, 1]
#
# Path from source to node 790
# [0, 1]
#
# Path from source to node 791
# [0, 1, 48]
#
# Path from source to node 792
# [0, 1, 47, 68, 87]
#
# Path from source to node 793
# [0, 1, 11, 44, 89]
#
# Path from source to node 794
# [0, 1, 30]
#
# Path from source to node 795
# [0, 1, 68]
#
# Path from source to node 796
# [0, 1]
#
# Path from source to node 797
# [0, 1]
#
# Path from source to node 798
# [0, 1]
#
# Path from source to node 799
# [0, 1, 11, 30, 44, 90]
#
# Path from source to node 800
# [0, 1, 11, 85, 425]
#
# Path from source to node 801
# [0, 1]
#
# Path from source to node 802
# [0, 1, 11, 134, 194]
#
# Path from source to node 803
# [0, 1, 11, 44, 48]
#
# Path from source to node 804
# [0, 1, 11]
#
# Path from source to node 805
# [0, 1, 11, 48]
#
# Path from source to node 806
# [0, 1, 11, 30, 68]
#
# Path from source to node 807
# [0, 1, 11, 44, 72]
#
# Path from source to node 808
# [0, 1, 30]
#
# Path from source to node 809
# [0, 1, 30]
#
# Path from source to node 810
# [0, 1, 30, 47]
#
# Path from source to node 811
# [0, 1, 11, 44]
#
# Path from source to node 812
# [0, 1, 44]
#
# Path from source to node 813
# [0, 1, 44, 136]
#
# Path from source to node 814
# [0, 1, 47, 63, 87]
#
# Path from source to node 815
# [0, 1, 30, 194]
#
# Path from source to node 816
# [0, 1, 47, 490]
#
# Path from source to node 817
# [0, 1, 11]
#
# Path from source to node 818
# [0, 1, 11, 44]
#
# Path from source to node 819
# [0, 1, 30, 47]
#
# Path from source to node 820
# [0, 1, 11, 47]
#
# Path from source to node 821
# [0, 1, 70]
#
# Path from source to node 822
# [0, 1, 11]
#
# Path from source to node 823
# [0, 1, 47, 68]
#
# Path from source to node 824
# [0, 1, 30, 89]
#
# Path from source to node 825
# [0, 1, 11, 68, 136]
#
# Path from source to node 826
# [0, 1]
#
# Path from source to node 827
# [0, 1, 11]
#
# Path from source to node 828
# [0, 1]
#
# Path from source to node 829
# [0, 1, 11, 103]
#
# Path from source to node 830
# [0, 1]
#
# Path from source to node 831
# [0, 1, 11, 44, 101]
#
# Path from source to node 832
# [0, 1, 11, 103]
#
# Path from source to node 833
# [0, 1, 11, 63, 305]
#
# Path from source to node 834
# [0, 1, 11, 68]
#
# Path from source to node 835
# [0, 1]
#
# Path from source to node 836
# [0, 1, 30, 44, 70]
#
# Path from source to node 837
# [0, 1, 70]
#
# Path from source to node 838
# [0, 1, 11, 44, 63]
#
# Path from source to node 839
# [0, 1]
#
# Path from source to node 840
# [0, 1, 11, 47]
#
# Path from source to node 841
# [0, 1, 90]
#
# Path from source to node 842
# [0, 1]
#
# Path from source to node 843
# [0, 1, 11, 30, 90]
#
# Path from source to node 844
# [0, 1]
#
# Path from source to node 845
# [0, 1, 103]
#
# Path from source to node 846
# [0, 1, 30, 85]
#
# Path from source to node 847
# [0, 1, 11, 68]
#
# Path from source to node 848
# [0, 1, 11, 112]
#
# Path from source to node 849
# [0, 1, 11, 30, 63]
#
# Path from source to node 850
# [0, 1, 47]
#
# Path from source to node 851
# [0, 1, 11, 30, 47]
#
# Path from source to node 852
# [0, 1, 11, 30]
#
# Path from source to node 853
# [0, 1, 11]
#
# Path from source to node 854
# [0, 1, 11, 30]
#
# Path from source to node 855
# [0, 1]
#
# Path from source to node 856
# [0, 1, 11]
#
# Path from source to node 857
# [0, 1, 44]
#
# Path from source to node 858
# [0, 1, 44, 48]
#
# Path from source to node 859
# [0, 1, 122]
#
# Path from source to node 860
# [0, 1, 11, 30, 63, 70]
#
# Path from source to node 861
# [0, 1, 30]
#
# Path from source to node 862
# [0, 1, 11, 44]
#
# Path from source to node 863
# [0, 1, 63, 101]
#
# Path from source to node 864
# [0, 1]
#
# Path from source to node 865
# [0, 1, 30, 44, 47]
#
# Path from source to node 866
# [0, 1, 30, 48, 691]
#
# Path from source to node 867
# [0, 1, 47, 48, 63]
#
# Path from source to node 868
# [0, 1, 63]
#
# Path from source to node 869
# [0, 1, 70]
#
# Path from source to node 870
# [0, 1, 70]
#
# Path from source to node 871
# [0, 1, 44, 47, 68]
#
# Path from source to node 872
# [0, 1, 63, 68]
#
# Path from source to node 873
# [0, 1, 11]
#
# Path from source to node 874
# [0, 1, 11, 30]
#
# Path from source to node 875
# [0, 1]
#
# Path from source to node 876
# [0, 1, 30, 44]
#
# Path from source to node 877
# [0, 1, 11, 72, 87, 117]
#
# Path from source to node 878
# [0, 1, 72]
#
# Path from source to node 879
# [0, 1, 11, 30, 44, 70]
#
# Path from source to node 880
# [0, 1, 11, 68, 125]
#
# Path from source to node 881
# [0, 1, 30, 87, 397]
#
# Path from source to node 882
# [0, 1, 44, 63]
#
# Path from source to node 883
# [0, 1, 11]
#
# Path from source to node 884
# [0, 1, 11, 48]
#
# Path from source to node 885
# [0, 1, 11, 122]
#
# Path from source to node 886
# [0, 1, 11, 63, 103, 136]
#
# Path from source to node 887
# [0, 1, 30, 44, 89]
#
# Path from source to node 888
# [0, 1, 30, 44]
#
# Path from source to node 889
# [0, 1, 44, 63, 89]
#
# Path from source to node 890
# [0, 1, 11, 44, 211]
#
# Path from source to node 891
# [0, 1, 11]
#
# Path from source to node 892
# [0, 1, 11, 30, 44]
#
# Path from source to node 893
# [0, 1, 11, 63, 70, 72]
#
# Path from source to node 894
# [0, 1, 30, 63, 163]
#
# Path from source to node 895
# [0, 1, 47, 68]
#
# Path from source to node 896
# [0, 1, 47]
#
# Path from source to node 897
# [0, 1, 11, 30, 68, 87]
#
# Path from source to node 898
# [0, 1, 11, 47]
#
# Path from source to node 899
# [0, 1, 44]
#
# Path from source to node 900
# [0, 1, 47, 68]
#
# Path from source to node 901
# [0, 1, 11, 68]
#
# Path from source to node 902
# [0, 1]
#
# Path from source to node 903
# [0, 1, 47, 87]
#
# Path from source to node 904
# [0, 1, 11, 30, 48]
#
# Path from source to node 905
# [0, 1, 47]
#
# Path from source to node 906
# [0, 1, 48]
#
# Path from source to node 907
# [0, 1, 63, 85]
#
# Path from source to node 908
# [0, 1, 11, 112, 163]
#
# Path from source to node 909
# [0, 1, 11, 30]
#
# Path from source to node 910
# [0, 1, 30]
#
# Path from source to node 911
# [0, 1]
#
# Path from source to node 912
# [0, 1, 11]
#
# Path from source to node 913
# [0, 1, 44, 63]
#
# Path from source to node 914
# [0, 1]
#
# Path from source to node 915
# [0, 1]
#
# Path from source to node 916
# [0, 1, 11, 48]
#
# Path from source to node 917
# [0, 1, 44]
#
# Path from source to node 918
# [0, 1, 72]
#
# Path from source to node 919
# [0, 1]
#
# Path from source to node 920
# [0, 1, 44]
#
# Path from source to node 921
# [0, 1, 70, 101, 134]
#
# Path from source to node 922
# [0, 1]
#
# Path from source to node 923
# [0, 1, 11, 30]
#
# Path from source to node 924
# [0, 1, 11, 30, 211]
#
# Path from source to node 925
# [0, 1, 30, 44]
#
# Path from source to node 926
# [0, 1]
#
# Path from source to node 927
# [0, 1, 11, 72]
#
# Path from source to node 928
# [0, 1, 30, 158]
#
# Path from source to node 929
# [0, 1, 72]
#
# Path from source to node 930
# [0, 1, 11, 44, 47]
#
# Path from source to node 931
# [0, 1, 48, 63, 87]
#
# Path from source to node 932
# [0, 1, 11, 48]
#
# Path from source to node 933
# [0, 1]
#
# Path from source to node 934
# [0, 1, 47, 211]
#
# Path from source to node 935
# [0, 1, 11]
#
# Path from source to node 936
# [0, 1]
#
# Path from source to node 937
# [0, 1, 11]
#
# Path from source to node 938
# [0, 1]
#
# Path from source to node 939
# [0, 1, 30, 72]
#
# Path from source to node 940
# [0, 1, 85]
#
# Path from source to node 941
# [0, 1, 89]
#
# Path from source to node 942
# [0, 1, 11, 30, 44, 68]
#
# Path from source to node 943
# [0, 1, 47, 48, 63]
#
# Path from source to node 944
# [0, 1, 70]
#
# Path from source to node 945
# [0, 1, 30]
#
# Path from source to node 946
# [0, 1, 30, 103]
#
# Path from source to node 947
# [0, 1, 30, 130]
#
# Path from source to node 948
# [0, 1, 11, 87]
#
# Path from source to node 949
# [0, 1]
#
# Path from source to node 950
# [0, 1, 30]
#
# Path from source to node 951
# [0, 1, 11]
#
# Path from source to node 952
# [0, 1, 11]
#
# Path from source to node 953
# [0, 1]
#
# Path from source to node 954
# [0, 1, 11, 30, 103, 292]
#
# Path from source to node 955
# [0, 1, 11, 70]
#
# Path from source to node 956
# [0, 1, 87, 122]
#
# Path from source to node 957
# [0, 1, 48, 87]
#
# Path from source to node 958
# [0, 1, 44]
#
# Path from source to node 959
# [0, 1, 30, 112]
#
# Path from source to node 960
# [0, 1]
#
# Path from source to node 961
# [0, 1, 11, 30, 47, 163]
#
# Path from source to node 962
# [0, 1, 11, 44]
#
# Path from source to node 963
# [0, 1]
#
# Path from source to node 964
# [0, 1, 44, 230]
#
# Path from source to node 965
# [0, 1, 11]
#
# Path from source to node 966
# [0, 1, 11, 103]
#
# Path from source to node 967
# [0, 1, 11, 44, 68]
#
# Path from source to node 968
# [0, 1, 11, 48]
#
# Path from source to node 969
# [0, 1, 48]
#
# Path from source to node 970
# [0, 1, 11, 87]
#
# Path from source to node 971
# [0, 1, 101]
#
# Path from source to node 972
# [0, 1, 44, 47, 48]
#
# Path from source to node 973
# [0, 1, 11, 63]
#
# Path from source to node 974
# [0, 1]
#
# Path from source to node 975
# [0, 1, 30]
#
# Path from source to node 976
# [0, 1, 44, 47]
#
# Path from source to node 977
# [0, 1, 44, 117, 134]
#
# Path from source to node 978
# [0, 1, 11]
#
# Path from source to node 979
# [0, 1, 11, 44, 47, 87]
#
# Path from source to node 980
# [0, 1, 101]
#
# Path from source to node 981
# [0, 1, 11]
#
# Path from source to node 982
# [0, 1, 30, 68]
#
# Path from source to node 983
# [0, 1, 44]
#
# Path from source to node 984
# [0, 1, 63, 70]
#
# Path from source to node 985
# [0, 1]
#
# Path from source to node 986
# [0, 1]
#
# Path from source to node 987
# [0, 1]
#
# Path from source to node 988
# [0, 1, 48, 89]
#
# Path from source to node 989
# [0, 1, 63]
#
# Path from source to node 990
# [0, 1, 48]
#
# Path from source to node 991
# [0, 1, 44, 89]
#
# Path from source to node 992
# [0, 1, 47]
#
# Path from source to node 993
# [0, 1]
#
# Path from source to node 994
# [0, 1, 30]
#
# Path from source to node 995
# [0, 1, 44, 48, 112, 122]
#
# Path from source to node 996
# [0, 1, 11]
#
# Path from source to node 997
# [0, 1, 48, 121, 122]
#
# Path from source to node 998
# [0, 1, 11, 30, 47, 72, 85]
#
# Path from source to node 999
# [0, 1]

# %% [markdown]
# Comparing the results of the 2 variations to see if they match

# %%
Error = False

for i in range(len(resultA)):
    if resultA[i] == resultB[i]:
        continue
    else:
        Error = True
        break
        
if (Error):
    print("Something went wrong")
    for i in range(len(resultA)):
        print("Node", i, resultA[i] == resultB[i])
else:
    print("Output for both variations are the same")
# Out:
# Output for both variations are the same
